# %%
from thermoift import Analyzer

result = Analyzer.load_csv("CSV/feed_1_interfacial_results.csv")
print(result["summary"])

report = Analyzer.report(
    filepath="CSV/feed_1_interfacial_results.csv",
    row_index=15
)

print(report["table"])
print(report["validation"])
# Out:
# {'components': ['argon', 'carbon dioxide', 'carbon monoxide', 'ethane', 'hydrogen', 'hydrogen sulfide', 'methane', 'nitrogen', 'nitrogen dioxide', 'nitrogen oxide', 'oxygen', 'propane', 'sulfur dioxide', 'water'], 'total_rows': 100, 'valid_rows': 100, 'invalid_rows': 0, 'all_valid': True, 'z_sum_range': (1.0, 1.0), 'x_sum_range': (0.9999999999999997, 1.0000000000000002), 'y_sum_range': (0.9999999999999998, 1.0000000000000002), 'gamma_range': (1.6709221505686394, 19.90299639009991), 'E_range': (0.0, 5.801511575878009), 'E_range_by_component': {'argon': (1.216127240614092, 5.801511575878009), 'carbon dioxide': (1.0, 1.000000001091972), 'carbon monoxide': (0.0, 0.0), 'ethane': (0.0, 0.0), 'hydrogen': (0.0, 0.0), 'hydrogen sulfide': (0.0, 0.0), 'methane': (0.0, 0.0), 'nitrogen': (0.0, 0.0), 'nitrogen dioxide': (0.0, 0.0), 'nitrogen oxide': (0.0, 0.0), 'oxygen': (0.0, 0.0), 'propane': (0.0, 0.0), 'sulfur dioxide': (0.0, 0.0), 'water': (0.0, 0.0)}}
# ...
