# %%
import time
notebook_start = time.perf_counter()

# %pip install -e /home/darshan/A6/PCSAFT_cDFT/thermoift

import feos, si_units as si, numpy as np, importlib.metadata
from pathlib import Path
from molmass import Formula
import thermoift.PLOT_SETTINGS as ps
import thermoift.FeosPlugin as TC
from thermoift import KIJ
from itertools import combinations

print(f"FEOS version used: {importlib.metadata.version('feos')}")
KIJ_DIR = Path(KIJ.__file__).parent
# Out:
# Obtaining file:///home/darshan/A6/PCSAFT_cDFT/thermoift
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: feos>=0.9.3 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (0.9.4)
# Requirement already satisfied: numpy in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (2.4.0)
# Requirement already satisfied: pandas in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (2.3.3)
# Requirement already satisfied: matplotlib in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (3.10.8)
# Requirement already satisfied: scipy in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (1.16.3)
# Requirement already satisfied: molmass==2026.1.8 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (2026.1.8)
# Requirement already satisfied: si-units==0.11.1 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (0.11.1)
# Requirement already satisfied: sympy==1.14.0 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (1.14.0)
# Requirement already satisfied: ctREFPROP==0.10.5 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (0.10.5)
# Requirement already satisfied: scienceplots in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (2.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from sympy==1.14.0->thermoift==0.2.0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (25.0)
# Requirement already satisfied: pillow>=8 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->thermoift==0.2.0) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from pandas->thermoift==0.2.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from pandas->thermoift==0.2.0) (2025.3)
# Building wheels for collected packages: thermoift
#   Building editable for thermoift (pyproject.toml) ... done
#   Created wheel for thermoift: filename=thermoift-0.2.0-0.editable-py3-none-any.whl size=1730 sha256=714301c56aca6fb294875650f6d0afc55a71dd9fbff468f82468a41412d993aa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-nf0x7z6j/wheels/fd/2f/c4/54a2ee5cd16a9bf5b183bbe5c28d1b3ba4926fb0261a13e1e4
# Successfully built thermoift
# Installing collected packages: thermoift
#   Attempting uninstall: thermoift
#     Found existing installation: thermoift 0.2.0
#     Uninstalling thermoift-0.2.0:
#       Successfully uninstalled thermoift-0.2.0
# Successfully installed thermoift-0.2.0
# Note: you may need to restart the kernel to use updated packages.
# FEOS version used: 0.9.4

# %%
# COMPONENTS          = ["carbon dioxide", "hydrogen", "argon", "nitrogen", "methane"]
# KIJ_map = {
#     ("CO2", "H2") : "linear",
#     ("CO2", "Ar") : "constant",
#     ("H2",  "Ar") : "linear",
#     ("CO2", "N2") : "constant",
#     ("CO2", "CH4"): "linear",
#     ("H2",  "N2") : "constant",
#     ("H2",  "CH4"): "constant",
#     ("Ar",  "N2") : "constant",
#     ("Ar",  "CH4"): "constant",
#     ("N2",  "CH4"): "constant",
# }

COMPONENTS  = ["carbon dioxide", "hydrogen", "argon"]
KIJ_map     = {
                ("CO2", "Ar")   : "constant",
                ("H2", "Ar")    : "zero",
                ("CO2", "H2")   : "zero"}

CO2_comp            = 0.95
feeds               = TC.make_feeds([CO2_comp, 0.02, 0.03])
builder             = KIJ.KIJMatrixBuilder(root = str(KIJ_DIR), kij_filename = "KIJ.json", verbose = False)
parameters          = TC.PARAMETERS(COMPONENTS, T_K= 300.0, kij_builder = builder, model_map = KIJ_map)  # Arbitrary T_K is to check whether KIJ are imported correctly
components          = TC.components(parameters)
KIJ_LABELS          = TC._kij_labels(COMPONENTS)
verbose             = True

builder.build_and_display(
    components          = KIJ_LABELS,
    model_map           = KIJ_map,
    T_eval              = 300.0,
    show_matrix         = True,
    show_pair_equations = True)

TC.print_array2d(feeds)

# FLASH and IFT computation settings
T_initial_guess     = 200
P_TOL               = 1e-4    # Pressure [bar] tolerance for flash calculations excempting at the saturation points
T_STEP              = 10       # Temperature step for bubble/dew curve calculations (K)
P_STEP              = 5       # Pressure step for flash calculations (bar)
PT_results          = {}
VLE_DFT             = {}
lgrid               = 100    # Length of the computational domain for the planar interface in Angstroms
ngrid               = 2048     # number of grid points required for the planar interface computation

# To plot all pair KIJ curves
# for c1, c2 in combinations(KIJ_LABELS, 2):
#     builder.show_pair_plot(c1, c2, mode="all")

builder.show_pair_plots(TC._kij_labels(COMPONENTS), mode="all")

parameters
# Out:
# K(300.0 K) =
# [[0.         0.         0.03481295]
#  [0.         0.         0.        ]
#  [0.03481295 0.         0.        ]]
#
# Symbolic K(T) matrix:
# Matrix([
# [     0, 0, 0.0348],
# [     0, 0,      0],
# [0.0348, 0,      0]])
# Pair equations:
# Eq(k_{CO2,H2}(T), 0)
# Eq(k_{CO2,Ar}(T), 0.0348)
# Eq(k_{H2,Ar}(T), 0)
#   i |         z1 |         z2 |         z3
# ---------------------------------------------------------
#   1 |       0.9500       0.0200       0.0300
# [
#   {
#     "identifier": {
#       "cas": "124-38-9",
#       "name": "carbon dioxide",
#       "iupac_name": "carbon dioxide"
#     },
#     "molarweight": 43.99,
#     "m": 2.53096,
#     "sigma": 2.57855,
#     "epsilon_k": 153.31864
#   },
#   {
#     "identifier": {
#       "cas": "1333-74-0",
#       "name": "hydrogen",
#       "iupac_name": "molecular hydrogen"
#     },
#     "molarweight": 2.016,
#     "m": 1.0,
#     "sigma": 3.002,
#     "epsilon_k": 51.343
#   },
#   {
#     "identifier": {
#       "cas": "7440-37-1",
#       "name": "argon",
#       "iupac_name": "argon"
#     },
#     "molarweight": 39.962,
#     "m": 1.0,
#     "sigma": 3.37751,
#     "epsilon_k": 117.80903
#   }
# ]
#
# [
#   {
#     "id1": 0,
#     "id2": 1,
#     "k_ij": 0.0
#   },
#   {
#     "id1": 0,
#     "id2": 2,
#     "k_ij": 0.03481294797303504
#   },
#   {
#     "id1": 1,
#     "id2": 2,
#     "k_ij": 0.0
#   }
# ]

# %%
# # TEST ---- FLASH and IFT computation settings
# T_initial_guess     = 200
# P_TOL               = 1e-2    # Pressure [bar] tolerance for flash calculations excempting at the saturation points
# T_STEP              = 10       # Temperature step for bubble/dew curve calculations (K)
# P_STEP              = 5       # Pressure step for flash calculations (bar)
# PT_results          = {}
# VLE_DFT             = {}
# lgrid               = 100    # Length of the computational domain for the planar interface in Angstroms
# ngrid               = 500     # number of grid points required for the planar interface computation

# %%
# ── Parameters & EOS (T-dependent kij rebuilt per temperature) ─────────────

for k, z in enumerate(feeds, start=1):
    
    # --- normalize + mole amounts ---
    z    = TC.normalize_z(z)
    feed = TC.compute_feed_moles(z)
    
    if verbose:
        print(f"\nFeed {k}: z = {z}") 
    
    # --- detect zero components and reduce if one of the component is zero ---
    active_z, active_components, is_reduced = TC.reduce_components(z, COMPONENTS, verbose=verbose)
    active_feed                             = TC.compute_feed_moles(active_z)
    active_map                              = TC.reduce_kij_map(active_components, KIJ_map)  
    
    # --- critical point (use a reference T for kij) ---
    parameters_ref  = TC.PARAMETERS(active_components,T_K = T_initial_guess, kij_builder = builder, model_map = active_map)
    eos             = feos.HelmholtzEnergyFunctional.pcsaft(parameters_ref)
    
    try:
        CT, CP = TC.compute_CT(feos, eos, active_z, T_guess=T_initial_guess)
        
        if verbose:
            print(f"Critical Point: T = {CT/si.KELVIN:.2f} K, P = {CP/si.BAR:.2f} bar")
    
        # ---- compute bubble and dew curves with T-dependent kij ----
        T_values       = range(int(T_initial_guess), int(CT / si.KELVIN) + 1, T_STEP)
        bubble_results = []
        dew_results    = []

        T_bubble_all, P_bubble_all = [], []
        T_dew_all,    P_dew_all    = [], []

        for T_K in T_values:
            # Rebuild parameters and eos at each temperature
            parameters_T = TC.PARAMETERS(active_components,T_K = float(T_K),kij_builder = builder, model_map = active_map)
            eos_T = feos.HelmholtzEnergyFunctional.pcsaft(parameters_T)

            T_bub, P_bub = TC.compute_bubble_curve(eos_T, [T_K], active_feed, verbose=verbose)
            T_dew, P_dew = TC.compute_dew_curve(eos_T,    [T_K], active_feed, verbose=verbose)

            T_bubble_all.extend(T_bub); P_bubble_all.extend(P_bub)
            T_dew_all.extend(T_dew);    P_dew_all.extend(P_dew)

        PT_results[f"feed_{k}"] = {
            "z":       [round(float(x), 6) for x in np.asarray(z, dtype=float)],
            "TC_K":    round(float(CT / si.KELVIN), 2),
            "PC_bar":  round(float(CP / si.BAR), 2),
            "bubble":  [{"T_K": float(T), "P_bar": float(P)} for T, P in zip(T_bubble_all, P_bubble_all)],
            "dew":     [{"T_K": float(T), "P_bar": float(P)} for T, P in zip(T_dew_all, P_dew_all)],
        }
    
    except Exception as e:
        print(f"Feed {k}: z = {z}")
        print("CT computation failed:", e)
# Out:
# Feed 1: z = [0.95 0.02 0.03]
# Critical Point: T = 305.78 K, P = 91.58 bar

# %%
######################## PT phase digram spcae sweep , TP flash, and cDFT computations #################
for feed_key, feed in PT_results.items():

    TP_z = np.array(feed.get("z", []))
    CT   = feed["TC_K"] * si.KELVIN
    CP   = feed["PC_bar"] * si.BAR
    
    # --- detect zero components and reduce if one of the component is zero ---
    active_z, active_components, is_reduced = TC.reduce_components(TP_z, COMPONENTS, verbose=verbose)
    active_feed                             = TC.compute_feed_moles(active_z)
    active_map                              = TC.reduce_kij_map(active_components, KIJ_map)
    
    fig, ax     = TC.plot_PT(PT_results, feed_key, parameters)
    
    bub         = {int(round(pt["T_K"])): float(pt["P_bar"]) for pt in feed.get("bubble", [])}
    dew         = {int(round(pt["T_K"])): float(pt["P_bar"]) for pt in feed.get("dew", [])}
    common_T    = sorted(set(bub) & set(dew))

    # ---- Initialize unified storage for this FIXED feed composition ----
    VLE_DFT[feed_key] = {
        "z": TP_z.tolist(),
        "phase_envelope": {
            "bubble_curve": [{"T_K": T, "P_bar": bub[T]} for T in sorted(bub.keys())],
            "dew_curve": [{"T_K": T, "P_bar": dew[T]} for T in sorted(dew.keys())],
            "isothermal_lines": [
                {"T_K": T, "P_bubble_bar": bub[T], "P_dew_bar": dew[T]} 
                for T in common_T
            ]
        },
        "interfacial_data": {}
    }
    
    if verbose:
        print(f"\n{feed_key}:")
        for T in common_T:
            print(f"  T = {T} K: P_bubble = {bub[T]:.2f} bar, P_dew = {dew[T]:.2f} bar")
    
    if common_T:
        
        for T in common_T:    
            
            # Rebuild parameters and eos at this temperature
            parameters_T        = TC.PARAMETERS(active_components, T_K = float(T), kij_builder = builder, model_map = active_map)
            eos_T               = feos.HelmholtzEnergyFunctional.pcsaft(parameters_T)
            molar_masses        = TC.molar_masses(parameters_T) # g/mol
            
            P_b = bub[T]
            P_d = dew[T]

            if P_b >= P_d:
                
                pressures = np.linspace(P_d + P_TOL, P_b - P_TOL, 10)
                
                # ---- optional: PLOT ----
                ax.plot([T, T], [P_d, P_b], linewidth=0.5, linestyle="--", color="k", alpha=0.3)
                
                # Initialize list for this temperature
                VLE_DFT[feed_key]["interfacial_data"][T] = []
                
                for P in pressures:
                    
                    if verbose:
                        print(f"T = {T} K | P_flash = {P:.2f} | z = {active_z}")
                       
                    # --- TP flash ---
                    try:
                        eq, x, y, liquid_density, vapor_density = TC.tp_flash(
                            feos, eos_T, T*si.KELVIN, P*si.BAR, active_z*si.MOL, molar_masses)
                    except Exception as e:
                        print(f"TP flash failed for z = {active_z} at T = {T} K, P = {P:.2f} bar: {e}")
                        continue
                    
                    # --- planar interface & surface tension ---
                    interface = TC.build_planar_interface(
                        eq, critical_temperature=CT, n_grid=ngrid, l_grid=lgrid)
                    
                    try:
                        gamma_mN_m, interfacial_thickness_nm, enrichment = \
                            TC.solve_interface_properties(interface, si)
                    except Exception as e:
                        print(f"Surface tension calculation failed for z = {active_z} at T = {T} K, P = {P:.2f} bar: {e}")
                        gamma_mN_m = np.nan
                        interfacial_thickness_nm = np.nan
                        enrichment = tuple(np.nan for _ in active_components)
                    
                    if verbose:
                        print(f"T = {T} K | P_flash = {P:.2f} bar | gamma = {gamma_mN_m:.6f} mN/m")

                    row_data = TC.row_append(
                        T_K=float(T),
                        P_bar=float(P),
                        z=active_z,
                        Tc=CT,
                        Pc=CP,
                        P_bubble=P_b,
                        P_dew=P_d,
                        liquid_density=liquid_density,
                        vapor_density=vapor_density,
                        x=x,
                        y=y,
                        gamma_mN_m=gamma_mN_m,
                        interfacial_thickness_nm=interfacial_thickness_nm,
                        components=active_components,
                        enrichment=enrichment,
                        ML_mode=False  # Use only active components
                    )
                    
                    # Store in interfacial_data
                    VLE_DFT[feed_key]["interfacial_data"][T].append(row_data)
                    
    TC.save_plot(fig, f"PT_{feed_key}")
    
    fig_gamma = TC.plot_gamma_colormap(PT_results, VLE_DFT, feed_key, parameters)
    if fig_gamma is not None:
        ps.save_plot(fig_gamma, f"Gamma_{feed_key}")

summary = TC.VLE_DFT_summary(VLE_DFT)

if verbose:
    print(summary)
  
saved_files = TC.VLE_DFT_to_csv(VLE_DFT, verbose=verbose)
# Out:
# feed_1:
#   T = 200 K: P_bubble = 63.94 bar, P_dew = 2.52 bar
#   T = 210 K: P_bubble = 60.59 bar, P_dew = 4.11 bar
#   T = 220 K: P_bubble = 58.52 bar, P_dew = 6.37 bar
#   T = 230 K: P_bubble = 57.66 bar, P_dew = 9.47 bar
#   T = 240 K: P_bubble = 58.03 bar, P_dew = 13.60 bar
#   T = 250 K: P_bubble = 59.67 bar, P_dew = 18.96 bar
#   T = 260 K: P_bubble = 62.68 bar, P_dew = 25.79 bar
#   T = 270 K: P_bubble = 67.14 bar, P_dew = 34.36 bar
#   T = 280 K: P_bubble = 73.13 bar, P_dew = 45.00 bar
#   T = 290 K: P_bubble = 80.62 bar, P_dew = 58.23 bar
#   T = 300 K: P_bubble = 89.09 bar, P_dew = 89.09 bar
# T = 200 K | P_flash = 2.52 | z = [0.95 0.02 0.03]
# T = 200 K | P_flash = 2.52 bar | gamma = 19.887404 mN/m
# T = 200 K | P_flash = 9.35 | z = [0.95 0.02 0.03]
# T = 200 K | P_flash = 9.35 bar | gamma = 18.717127 mN/m
# T = 200 K | P_flash = 16.17 | z = [0.95 0.02 0.03]
# T = 200 K | P_flash = 16.17 bar | gamma = 17.796095 mN/m
# T = 200 K | P_flash = 22.99 | z = [0.95 0.02 0.03]
# T = 200 K | P_flash = 22.99 bar | gamma = 17.065500 mN/m
# T = 200 K | P_flash = 29.82 | z = [0.95 0.02 0.03]
# T = 200 K | P_flash = 29.82 bar | gamma = 16.463880 mN/m
# T = 200 K | P_flash = 36.64 | z = [0.95 0.02 0.03]
# T = 200 K | P_flash = 36.64 bar | gamma = 15.946873 mN/m
# T = 200 K | P_flash = 43.47 | z = [0.95 0.02 0.03]
# T = 200 K | P_flash = 43.47 bar | gamma = 15.486875 mN/m
# T = 200 K | P_flash = 50.29 | z = [0.95 0.02 0.03]
# T = 200 K | P_flash = 50.29 bar | gamma = 15.067289 mN/m
# T = 200 K | P_flash = 57.11 | z = [0.95 0.02 0.03]
# T = 200 K | P_flash = 57.11 bar | gamma = 14.677963 mN/m
# T = 200 K | P_flash = 63.94 | z = [0.95 0.02 0.03]
# T = 200 K | P_flash = 63.94 bar | gamma = 14.312464 mN/m
# T = 210 K | P_flash = 4.11 | z = [0.95 0.02 0.03]
# T = 210 K | P_flash = 4.11 bar | gamma = 17.539178 mN/m
# T = 210 K | P_flash = 10.38 | z = [0.95 0.02 0.03]
# T = 210 K | P_flash = 10.38 bar | gamma = 16.635541 mN/m
# T = 210 K | P_flash = 16.66 | z = [0.95 0.02 0.03]
# T = 210 K | P_flash = 16.66 bar | gamma = 15.893742 mN/m
# T = 210 K | P_flash = 22.94 | z = [0.95 0.02 0.03]
# T = 210 K | P_flash = 22.94 bar | gamma = 15.283819 mN/m
# T = 210 K | P_flash = 29.21 | z = [0.95 0.02 0.03]
# T = 210 K | P_flash = 29.21 bar | gamma = 14.770436 mN/m
# T = 210 K | P_flash = 35.49 | z = [0.95 0.02 0.03]
# T = 210 K | P_flash = 35.49 bar | gamma = 14.324492 mN/m
# T = 210 K | P_flash = 41.76 | z = [0.95 0.02 0.03]
# T = 210 K | P_flash = 41.76 bar | gamma = 13.925815 mN/m
# T = 210 K | P_flash = 48.04 | z = [0.95 0.02 0.03]
# T = 210 K | P_flash = 48.04 bar | gamma = 13.561319 mN/m
# T = 210 K | P_flash = 54.31 | z = [0.95 0.02 0.03]
# Surface tension calculation failed for z = [0.95 0.02 0.03] at T = 210 K, P = 54.31 bar: `DFT` did not converge within the maximum number of iterations.
# T = 210 K | P_flash = 54.31 bar | gamma = nan mN/m
# T = 210 K | P_flash = 60.59 | z = [0.95 0.02 0.03]
# T = 210 K | P_flash = 60.59 bar | gamma = 12.904053 mN/m
# T = 220 K | P_flash = 6.37 | z = [0.95 0.02 0.03]
# T = 220 K | P_flash = 6.37 bar | gamma = 15.246401 mN/m
# T = 220 K | P_flash = 12.16 | z = [0.95 0.02 0.03]
# T = 220 K | P_flash = 12.16 bar | gamma = 14.540387 mN/m
# T = 220 K | P_flash = 17.96 | z = [0.95 0.02 0.03]
# T = 220 K | P_flash = 17.96 bar | gamma = 13.941712 mN/m
# T = 220 K | P_flash = 23.75 | z = [0.95 0.02 0.03]
# T = 220 K | P_flash = 23.75 bar | gamma = 13.434562 mN/m
# T = 220 K | P_flash = 29.54 | z = [0.95 0.02 0.03]
# T = 220 K | P_flash = 29.54 bar | gamma = 12.998716 mN/m
# T = 220 K | P_flash = 35.34 | z = [0.95 0.02 0.03]
# T = 220 K | P_flash = 35.34 bar | gamma = 12.615618 mN/m
# T = 220 K | P_flash = 41.13 | z = [0.95 0.02 0.03]
# T = 220 K | P_flash = 41.13 bar | gamma = 12.271099 mN/m
# T = 220 K | P_flash = 46.93 | z = [0.95 0.02 0.03]
# T = 220 K | P_flash = 46.93 bar | gamma = 11.955194 mN/m
# T = 220 K | P_flash = 52.72 | z = [0.95 0.02 0.03]
# T = 220 K | P_flash = 52.72 bar | gamma = 11.661115 mN/m
# T = 220 K | P_flash = 58.52 | z = [0.95 0.02 0.03]
# T = 220 K | P_flash = 58.52 bar | gamma = 11.384247 mN/m
# T = 230 K | P_flash = 9.47 | z = [0.95 0.02 0.03]
# T = 230 K | P_flash = 9.47 bar | gamma = 13.015553 mN/m
# T = 230 K | P_flash = 14.82 | z = [0.95 0.02 0.03]
# T = 230 K | P_flash = 14.82 bar | gamma = 12.460322 mN/m
# T = 230 K | P_flash = 20.18 | z = [0.95 0.02 0.03]
# T = 230 K | P_flash = 20.18 bar | gamma = 11.977262 mN/m
# T = 230 K | P_flash = 25.53 | z = [0.95 0.02 0.03]
# T = 230 K | P_flash = 25.53 bar | gamma = 11.557753 mN/m
# T = 230 K | P_flash = 30.89 | z = [0.95 0.02 0.03]
# T = 230 K | P_flash = 30.89 bar | gamma = 11.190268 mN/m
# T = 230 K | P_flash = 36.24 | z = [0.95 0.02 0.03]
# T = 230 K | P_flash = 36.24 bar | gamma = 10.863291 mN/m
# T = 230 K | P_flash = 41.59 | z = [0.95 0.02 0.03]
# T = 230 K | P_flash = 41.59 bar | gamma = 10.567209 mN/m
# T = 230 K | P_flash = 46.95 | z = [0.95 0.02 0.03]
# T = 230 K | P_flash = 46.95 bar | gamma = 10.294723 mN/m
# T = 230 K | P_flash = 52.30 | z = [0.95 0.02 0.03]
# T = 230 K | P_flash = 52.30 bar | gamma = 10.040579 mN/m
# T = 230 K | P_flash = 57.66 | z = [0.95 0.02 0.03]
# T = 230 K | P_flash = 57.66 bar | gamma = 9.801022 mN/m
# T = 240 K | P_flash = 13.60 | z = [0.95 0.02 0.03]
# T = 240 K | P_flash = 13.60 bar | gamma = 10.855012 mN/m
# T = 240 K | P_flash = 18.54 | z = [0.95 0.02 0.03]
# T = 240 K | P_flash = 18.54 bar | gamma = 10.418054 mN/m
# T = 240 K | P_flash = 23.47 | z = [0.95 0.02 0.03]
# T = 240 K | P_flash = 23.47 bar | gamma = 10.029815 mN/m
# T = 240 K | P_flash = 28.41 | z = [0.95 0.02 0.03]
# T = 240 K | P_flash = 28.41 bar | gamma = 9.685534 mN/m
# T = 240 K | P_flash = 33.34 | z = [0.95 0.02 0.03]
# T = 240 K | P_flash = 33.34 bar | gamma = 9.378681 mN/m
# T = 240 K | P_flash = 38.28 | z = [0.95 0.02 0.03]
# T = 240 K | P_flash = 38.28 bar | gamma = 9.102294 mN/m
# T = 240 K | P_flash = 43.22 | z = [0.95 0.02 0.03]
# T = 240 K | P_flash = 43.22 bar | gamma = 8.850106 mN/m
# T = 240 K | P_flash = 48.15 | z = [0.95 0.02 0.03]
# T = 240 K | P_flash = 48.15 bar | gamma = 8.617013 mN/m
# T = 240 K | P_flash = 53.09 | z = [0.95 0.02 0.03]
# T = 240 K | P_flash = 53.09 bar | gamma = 8.399093 mN/m
# T = 240 K | P_flash = 58.03 | z = [0.95 0.02 0.03]
# T = 240 K | P_flash = 58.03 bar | gamma = 8.193420 mN/m
# T = 250 K | P_flash = 18.96 | z = [0.95 0.02 0.03]
# T = 250 K | P_flash = 18.96 bar | gamma = 8.775691 mN/m
# T = 250 K | P_flash = 23.49 | z = [0.95 0.02 0.03]
# T = 250 K | P_flash = 23.49 bar | gamma = 8.434012 mN/m
# T = 250 K | P_flash = 28.01 | z = [0.95 0.02 0.03]
# T = 250 K | P_flash = 28.01 bar | gamma = 8.124985 mN/m
# T = 250 K | P_flash = 32.53 | z = [0.95 0.02 0.03]
# T = 250 K | P_flash = 32.53 bar | gamma = 7.845995 mN/m
# T = 250 K | P_flash = 37.06 | z = [0.95 0.02 0.03]
# T = 250 K | P_flash = 37.06 bar | gamma = 7.593405 mN/m
# T = 250 K | P_flash = 41.58 | z = [0.95 0.02 0.03]
# T = 250 K | P_flash = 41.58 bar | gamma = 7.363151 mN/m
# T = 250 K | P_flash = 46.10 | z = [0.95 0.02 0.03]
# T = 250 K | P_flash = 46.10 bar | gamma = 7.151334 mN/m
# T = 250 K | P_flash = 50.63 | z = [0.95 0.02 0.03]
# T = 250 K | P_flash = 50.63 bar | gamma = 6.954565 mN/m
# T = 250 K | P_flash = 55.15 | z = [0.95 0.02 0.03]
# T = 250 K | P_flash = 55.15 bar | gamma = 6.770074 mN/m
# T = 250 K | P_flash = 59.67 | z = [0.95 0.02 0.03]
# T = 250 K | P_flash = 59.67 bar | gamma = 6.595682 mN/m
# T = 260 K | P_flash = 25.79 | z = [0.95 0.02 0.03]
# T = 260 K | P_flash = 25.79 bar | gamma = 6.792178 mN/m
# T = 260 K | P_flash = 29.89 | z = [0.95 0.02 0.03]
# T = 260 K | P_flash = 29.89 bar | gamma = 6.529305 mN/m
# T = 260 K | P_flash = 33.99 | z = [0.95 0.02 0.03]
# T = 260 K | P_flash = 33.99 bar | gamma = 6.287860 mN/m
# T = 260 K | P_flash = 38.09 | z = [0.95 0.02 0.03]
# T = 260 K | P_flash = 38.09 bar | gamma = 6.066436 mN/m
# T = 260 K | P_flash = 42.19 | z = [0.95 0.02 0.03]
# T = 260 K | P_flash = 42.19 bar | gamma = 5.863077 mN/m
# T = 260 K | P_flash = 46.29 | z = [0.95 0.02 0.03]
# T = 260 K | P_flash = 46.29 bar | gamma = 5.675524 mN/m
# T = 260 K | P_flash = 50.38 | z = [0.95 0.02 0.03]
# T = 260 K | P_flash = 50.38 bar | gamma = 5.501499 mN/m
# T = 260 K | P_flash = 54.48 | z = [0.95 0.02 0.03]
# T = 260 K | P_flash = 54.48 bar | gamma = 5.338899 mN/m
# T = 260 K | P_flash = 58.58 | z = [0.95 0.02 0.03]
# T = 260 K | P_flash = 58.58 bar | gamma = 5.185901 mN/m
# T = 260 K | P_flash = 62.68 | z = [0.95 0.02 0.03]
# T = 260 K | P_flash = 62.68 bar | gamma = 5.040990 mN/m
# T = 270 K | P_flash = 34.36 | z = [0.95 0.02 0.03]
# T = 270 K | P_flash = 34.36 bar | gamma = 4.924840 mN/m
# T = 270 K | P_flash = 38.00 | z = [0.95 0.02 0.03]
# T = 270 K | P_flash = 38.00 bar | gamma = 4.728953 mN/m
# T = 270 K | P_flash = 41.64 | z = [0.95 0.02 0.03]
# T = 270 K | P_flash = 41.64 bar | gamma = 4.546572 mN/m
# T = 270 K | P_flash = 45.28 | z = [0.95 0.02 0.03]
# T = 270 K | P_flash = 45.28 bar | gamma = 4.376962 mN/m
# T = 270 K | P_flash = 48.93 | z = [0.95 0.02 0.03]
# T = 270 K | P_flash = 48.93 bar | gamma = 4.219127 mN/m
# T = 270 K | P_flash = 52.57 | z = [0.95 0.02 0.03]
# T = 270 K | P_flash = 52.57 bar | gamma = 4.071904 mN/m
# T = 270 K | P_flash = 56.21 | z = [0.95 0.02 0.03]
# T = 270 K | P_flash = 56.21 bar | gamma = 3.934072 mN/m
# T = 270 K | P_flash = 59.86 | z = [0.95 0.02 0.03]
# T = 270 K | P_flash = 59.86 bar | gamma = 3.804447 mN/m
# T = 270 K | P_flash = 63.50 | z = [0.95 0.02 0.03]
# T = 270 K | P_flash = 63.50 bar | gamma = 3.681944 mN/m
# T = 270 K | P_flash = 67.14 | z = [0.95 0.02 0.03]
# T = 270 K | P_flash = 67.14 bar | gamma = 3.565613 mN/m
# T = 280 K | P_flash = 45.00 | z = [0.95 0.02 0.03]
# T = 280 K | P_flash = 45.00 bar | gamma = 3.204019 mN/m
# T = 280 K | P_flash = 48.13 | z = [0.95 0.02 0.03]
# T = 280 K | P_flash = 48.13 bar | gamma = 3.066853 mN/m
# T = 280 K | P_flash = 51.25 | z = [0.95 0.02 0.03]
# T = 280 K | P_flash = 51.25 bar | gamma = 2.937588 mN/m
# T = 280 K | P_flash = 54.38 | z = [0.95 0.02 0.03]
# T = 280 K | P_flash = 54.38 bar | gamma = 2.815865 mN/m
# T = 280 K | P_flash = 57.50 | z = [0.95 0.02 0.03]
# T = 280 K | P_flash = 57.50 bar | gamma = 2.701224 mN/m
# T = 280 K | P_flash = 60.63 | z = [0.95 0.02 0.03]
# T = 280 K | P_flash = 60.63 bar | gamma = 2.593128 mN/m
# T = 280 K | P_flash = 63.75 | z = [0.95 0.02 0.03]
# T = 280 K | P_flash = 63.75 bar | gamma = 2.491008 mN/m
# T = 280 K | P_flash = 66.88 | z = [0.95 0.02 0.03]
# T = 280 K | P_flash = 66.88 bar | gamma = 2.394288 mN/m
# T = 280 K | P_flash = 70.00 | z = [0.95 0.02 0.03]
# T = 280 K | P_flash = 70.00 bar | gamma = 2.302417 mN/m
# T = 280 K | P_flash = 73.13 | z = [0.95 0.02 0.03]
# T = 280 K | P_flash = 73.13 bar | gamma = 2.214885 mN/m
# T = 290 K | P_flash = 58.23 | z = [0.95 0.02 0.03]
# T = 290 K | P_flash = 58.23 bar | gamma = 1.679984 mN/m
# T = 290 K | P_flash = 60.72 | z = [0.95 0.02 0.03]
# T = 290 K | P_flash = 60.72 bar | gamma = 1.596295 mN/m
# T = 290 K | P_flash = 63.21 | z = [0.95 0.02 0.03]
# T = 290 K | P_flash = 63.21 bar | gamma = 1.516592 mN/m
# T = 290 K | P_flash = 65.69 | z = [0.95 0.02 0.03]
# T = 290 K | P_flash = 65.69 bar | gamma = 1.440725 mN/m
# T = 290 K | P_flash = 68.18 | z = [0.95 0.02 0.03]
# T = 290 K | P_flash = 68.18 bar | gamma = 1.368518 mN/m
# T = 290 K | P_flash = 70.67 | z = [0.95 0.02 0.03]
# T = 290 K | P_flash = 70.67 bar | gamma = 1.299774 mN/m
# T = 290 K | P_flash = 73.16 | z = [0.95 0.02 0.03]
# Surface tension calculation failed for z = [0.95 0.02 0.03] at T = 290 K, P = 73.16 bar: `DFT` did not converge within the maximum number of iterations.
# T = 290 K | P_flash = 73.16 bar | gamma = nan mN/m
# T = 290 K | P_flash = 75.64 | z = [0.95 0.02 0.03]
# T = 290 K | P_flash = 75.64 bar | gamma = 1.171845 mN/m
# T = 290 K | P_flash = 78.13 | z = [0.95 0.02 0.03]
# T = 290 K | P_flash = 78.13 bar | gamma = 1.112234 mN/m
# T = 290 K | P_flash = 80.62 | z = [0.95 0.02 0.03]
# T = 290 K | P_flash = 80.62 bar | gamma = 1.055258 mN/m
# Available feeds: ['feed_1']
# feed_1: 11 bubble pts, 11 dew pts, 10 isotherms, 100 interfacial pts
# {'feed_1': {'n_bubble_points': 11, 'n_dew_points': 11, 'n_isotherms': 10, 'total_interfacial_points': 100}}
# Saved 100 rows to CSV/interfacial_results/feed_1_interfacial_results.csv
# Saved phase envelope data to CSV/phase_envelope/feed_1_phase_envelope.csv

# %%
notebook_end    = time.perf_counter()
elapsed_minutes = (notebook_end - notebook_start) / 60
print(f"Total notebook runtime: {elapsed_minutes:.2f} minutes")
# Out:
# Total notebook runtime: 0.85 minutes
