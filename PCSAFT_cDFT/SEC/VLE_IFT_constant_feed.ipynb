# %%
import time
notebook_start = time.perf_counter()

# %pip install -e /home/darshan/A6/PCSAFT_cDFT/thermoift

import feos, si_units as si, numpy as np, importlib.metadata
from pathlib import Path
from molmass import Formula
import thermoift.PLOT_SETTINGS as ps
import thermoift.FeosPlugin as TC
from thermoift import KIJ
from itertools import combinations

print(f"FEOS version used: {importlib.metadata.version('feos')}")
KIJ_DIR = Path(KIJ.__file__).parent
# Out:
# Obtaining file:///home/darshan/A6/PCSAFT_cDFT/thermoift
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: feos>=0.9.3 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (0.9.4)
# Requirement already satisfied: numpy in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (2.4.0)
# Requirement already satisfied: pandas in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (2.3.3)
# Requirement already satisfied: matplotlib in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (3.10.8)
# Requirement already satisfied: scipy in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (1.16.3)
# Requirement already satisfied: molmass==2026.1.8 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (2026.1.8)
# Requirement already satisfied: si-units==0.11.1 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (0.11.1)
# Requirement already satisfied: sympy==1.14.0 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (1.14.0)
# Requirement already satisfied: ctREFPROP==0.10.5 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (0.10.5)
# Requirement already satisfied: scienceplots in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from thermoift==0.2.0) (2.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from sympy==1.14.0->thermoift==0.2.0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (25.0)
# Requirement already satisfied: pillow>=8 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from matplotlib->thermoift==0.2.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->thermoift==0.2.0) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from pandas->thermoift==0.2.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/darshan/A6/py_A6/lib/python3.12/site-packages (from pandas->thermoift==0.2.0) (2025.3)
# Building wheels for collected packages: thermoift
#   Building editable for thermoift (pyproject.toml) ... done
#   Created wheel for thermoift: filename=thermoift-0.2.0-0.editable-py3-none-any.whl size=1730 sha256=6a644594e416d1008ea4045e7c07d9ad4bb3071baf731b91071e76b75d9532a1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-90n_pljq/wheels/fd/2f/c4/54a2ee5cd16a9bf5b183bbe5c28d1b3ba4926fb0261a13e1e4
# Successfully built thermoift
# Installing collected packages: thermoift
#   Attempting uninstall: thermoift
#     Found existing installation: thermoift 0.2.0
#     Uninstalling thermoift-0.2.0:
#       Successfully uninstalled thermoift-0.2.0
# Successfully installed thermoift-0.2.0
# Note: you may need to restart the kernel to use updated packages.
# FEOS version used: 0.9.4

# %%
COMPONENTS          = ["carbon dioxide", "hydrogen", "argon", "nitrogen", "methane"]
KIJ_map = {
    ("CO2", "H2") : "linear",
    ("CO2", "Ar") : "constant",
    ("H2",  "Ar") : "linear",
    ("CO2", "N2") : "constant",
    ("CO2", "CH4"): "linear",
    ("H2",  "N2") : "constant",
    ("H2",  "CH4"): "constant",
    ("Ar",  "N2") : "constant",
    ("Ar",  "CH4"): "constant",
    ("N2",  "CH4"): "constant",
}
CO2_comp            = 0.96
feeds               = TC.make_feeds([CO2_comp, 0.003, 0.007, 0.020, 0.010])
builder             = KIJ.KIJMatrixBuilder(root = str(KIJ_DIR), kij_filename = "KIJ.json", verbose = False)
parameters          = TC.PARAMETERS(COMPONENTS, T_K= 300.0, kij_builder = builder, model_map = KIJ_map)  # Arbitrary T_K is to check whether KIJ are imported correctly
components          = TC.components(parameters)
KIJ_LABELS          = TC._kij_labels(COMPONENTS)
verbose             = True

builder.build_and_display(
    components          = KIJ_LABELS,
    model_map           = KIJ_map,
    T_eval              = 300.0,
    show_matrix         = True,
    show_pair_equations = True)

TC.print_array2d(feeds)

# FLASH and IFT computation settings
T_initial_guess     = 200
P_TOL               = 1e-4    # Pressure [bar] tolerance for flash calculations excempting at the saturation points
T_STEP              = 10       # Temperature step for bubble/dew curve calculations (K)
P_STEP              = 5       # Pressure step for flash calculations (bar)
PT_results          = {}
VLE_DFT             = {}
lgrid               = 100    # Length of the computational domain for the planar interface in Angstroms
ngrid               = 2048     # number of grid points required for the planar interface computation

# To plot all pair KIJ curves
# for c1, c2 in combinations(KIJ_LABELS, 2):
#     builder.show_pair_plot(c1, c2, mode="all")

builder.show_pair_plots(TC._kij_labels(COMPONENTS), mode="all")

parameters
# Out:
# K(300.0 K) =
# [[ 0.         -0.00395506  0.03481295 -0.02907179  0.05809769]
#  [-0.00395506  0.          0.21992654  0.23107175  0.17675567]
#  [ 0.03481295  0.21992654  0.         -0.00610567  0.01942321]
#  [-0.02907179  0.23107175 -0.00610567  0.          0.03048489]
#  [ 0.05809769  0.17675567  0.01942321  0.03048489  0.        ]]
#
# Symbolic K(T) matrix:
# Matrix([
# [              0,   0.293 - 0.001*T,            0.0348, -0.0291, 0.0664],
# [0.293 - 0.001*T,                 0, 0.0002*T + 0.1557,  0.2311, 0.1768],
# [         0.0348, 0.0002*T + 0.1557,                 0, -0.0061, 0.0194],
# [        -0.0291,            0.2311,           -0.0061,       0, 0.0305],
# [         0.0664,            0.1768,            0.0194,  0.0305,      0]])
# Pair equations:
# Eq(k_{CO2,H2}(T), 0.293 - 0.001*T)
# Eq(k_{CO2,Ar}(T), 0.0348)
# Eq(k_{CO2,N2}(T), -0.0291)
# Eq(k_{CO2,CH4}(T), 0.0664)
# Eq(k_{H2,Ar}(T), 0.0002*T + 0.1557)
# Eq(k_{H2,N2}(T), 0.2311)
# Eq(k_{H2,CH4}(T), 0.1768)
# Eq(k_{Ar,N2}(T), -0.0061)
# Eq(k_{Ar,CH4}(T), 0.0194)
# Eq(k_{N2,CH4}(T), 0.0305)
#   i |         z1 |         z2 |         z3 |         z4 |         z5
# -------------------------------------------------------------------------------------
#   1 |       0.9600       0.0030       0.0070       0.0200       0.0100
# [
#   {
#     "identifier": {
#       "cas": "124-38-9",
#       "name": "carbon dioxide",
#       "iupac_name": "carbon dioxide"
#     },
#     "molarweight": 43.99,
#     "m": 2.53096,
#     "sigma": 2.57855,
#     "epsilon_k": 153.31864
#   },
#   {
#     "identifier": {
#       "cas": "1333-74-0",
#       "name": "hydrogen",
#       "iupac_name": "molecular hydrogen"
#     },
#     "molarweight": 2.016,
#     "m": 1.0,
#     "sigma": 3.002,
#     "epsilon_k": 51.343
#   },
#   {
#     "identifier": {
#       "cas": "7440-37-1",
#       "name": "argon",
#       "iupac_name": "argon"
#     },
#     "molarweight": 39.962,
#     "m": 1.0,
#     "sigma": 3.37751,
#     "epsilon_k": 117.80903
#   },
#   {
#     "identifier": {
#       "cas": "7727-37-9",
#       "name": "nitrogen",
#       "iupac_name": "molecular nitrogen"
#     },
#     "molarweight": 28.006,
#     "m": 1.23831,
#     "sigma": 3.30009,
#     "epsilon_k": 89.41358
#   },
#   {
#     "identifier": {
#       "cas": "74-82-8",
#       "name": "methane",
#       "iupac_name": "methane"
#     },
#     "molarweight": 16.031,
#     "m": 1.0,
#     "sigma": 3.70051,
#     "epsilon_k": 150.07147
#   }
# ]
#
# [
#   {
#     "id1": 0,
#     "id2": 1,
#     "k_ij": -0.003955056330330664
#   },
#   {
#     "id1": 0,
#     "id2": 2,
#     "k_ij": 0.03481294797303504
#   },
#   {
#     "id1": 0,
#     "id2": 3,
#     "k_ij": -0.029071786343496022
#   },
#   {
#     "id1": 0,
#     "id2": 4,
#     "k_ij": 0.058097688976607574
#   },
#   {
#     "id1": 1,
#     "id2": 2,
#     "k_ij": 0.21992654064301148
#   },
#   {
#     "id1": 1,
#     "id2": 3,
#     "k_ij": 0.23107174743939032
#   },
#   {
#     "id1": 1,
#     "id2": 4,
#     "k_ij": 0.17675567238114653
#   },
#   {
#     "id1": 2,
#     "id2": 3,
#     "k_ij": -0.00610566808912386
#   },
#   {
#     "id1": 2,
#     "id2": 4,
#     "k_ij": 0.01942321453247142
#   },
#   {
#     "id1": 3,
#     "id2": 4,
#     "k_ij": 0.030484885632331253
#   }
# ]

# %%
# # TEST ---- FLASH and IFT computation settings
# T_initial_guess     = 200
# P_TOL               = 1e-2    # Pressure [bar] tolerance for flash calculations excempting at the saturation points
# T_STEP              = 10       # Temperature step for bubble/dew curve calculations (K)
# P_STEP              = 5       # Pressure step for flash calculations (bar)
# PT_results          = {}
# VLE_DFT             = {}
# lgrid               = 100    # Length of the computational domain for the planar interface in Angstroms
# ngrid               = 500     # number of grid points required for the planar interface computation

# %%
# ── Parameters & EOS (T-dependent kij rebuilt per temperature) ─────────────

for k, z in enumerate(feeds, start=1):
    
    # --- normalize + mole amounts ---
    z    = TC.normalize_z(z)
    feed = TC.compute_feed_moles(z)
    
    if verbose:
        print(f"\nFeed {k}: z = {z}") 
    
    # --- detect zero components and reduce if one of the component is zero ---
    active_z, active_components, is_reduced = TC.reduce_components(z, COMPONENTS, verbose=verbose)
    active_feed                             = TC.compute_feed_moles(active_z)
    active_map                              = TC.reduce_kij_map(active_components, KIJ_map)  
    
    # --- critical point (use a reference T for kij) ---
    parameters_ref  = TC.PARAMETERS(active_components,T_K = T_initial_guess, kij_builder = builder, model_map = active_map)
    eos             = feos.HelmholtzEnergyFunctional.pcsaft(parameters_ref)
    
    try:
        CT, CP = TC.compute_CT(feos, eos, active_z, T_guess=T_initial_guess)
        
        if verbose:
            print(f"Critical Point: T = {CT/si.KELVIN:.2f} K, P = {CP/si.BAR:.2f} bar")
    
        # ---- compute bubble and dew curves with T-dependent kij ----
        T_values       = range(int(T_initial_guess), int(CT / si.KELVIN) + 1, T_STEP)
        bubble_results = []
        dew_results    = []

        T_bubble_all, P_bubble_all = [], []
        T_dew_all,    P_dew_all    = [], []

        for T_K in T_values:
            # Rebuild parameters and eos at each temperature
            parameters_T = TC.PARAMETERS(active_components,T_K = float(T_K),kij_builder = builder, model_map = active_map)
            eos_T = feos.HelmholtzEnergyFunctional.pcsaft(parameters_T)

            T_bub, P_bub = TC.compute_bubble_curve(eos_T, [T_K], active_feed, verbose=verbose)
            T_dew, P_dew = TC.compute_dew_curve(eos_T,    [T_K], active_feed, verbose=verbose)

            T_bubble_all.extend(T_bub); P_bubble_all.extend(P_bub)
            T_dew_all.extend(T_dew);    P_dew_all.extend(P_dew)

        PT_results[f"feed_{k}"] = {
            "z":       [round(float(x), 6) for x in np.asarray(z, dtype=float)],
            "TC_K":    round(float(CT / si.KELVIN), 2),
            "PC_bar":  round(float(CP / si.BAR), 2),
            "bubble":  [{"T_K": float(T), "P_bar": float(P)} for T, P in zip(T_bubble_all, P_bubble_all)],
            "dew":     [{"T_K": float(T), "P_bar": float(P)} for T, P in zip(T_dew_all, P_dew_all)],
        }
    
    except Exception as e:
        print(f"Feed {k}: z = {z}")
        print("CT computation failed:", e)
# Out:
# Feed 1: z = [0.96  0.003 0.007 0.02  0.01 ]
# Critical Point: T = 306.00 K, P = 87.09 bar
# Bubble calculation failed at T = 299 K: Iteration resulted in trivial solution.
# Dew calculation failed at T = 299 K: Iteration resulted in trivial solution.
# Bubble calculation failed at T = 300 K: Iteration resulted in trivial solution.
# Dew calculation failed at T = 300 K: Iteration resulted in trivial solution.
# Bubble calculation failed at T = 301 K: Iteration resulted in trivial solution.
# Dew calculation failed at T = 301 K: Iteration resulted in trivial solution.
# Bubble calculation failed at T = 303 K: Iteration resulted in trivial solution.
# Bubble calculation failed at T = 304 K: Iteration resulted in trivial solution.
# Bubble calculation failed at T = 305 K: Iteration resulted in trivial solution.
# Dew calculation failed at T = 305 K: Iteration resulted in trivial solution.
# Bubble calculation failed at T = 306 K: Iteration resulted in trivial solution.
# Dew calculation failed at T = 306 K: Iteration resulted in trivial solution.

# %%
######################## PT phase digram spcae sweep , TP flash, and cDFT computations #################
for feed_key, feed in PT_results.items():

    TP_z = np.array(feed.get("z", []))
    CT   = feed["TC_K"] * si.KELVIN
    CP   = feed["PC_bar"] * si.BAR
    
    # --- detect zero components and reduce if one of the component is zero ---
    active_z, active_components, is_reduced = TC.reduce_components(TP_z, COMPONENTS, verbose=verbose)
    active_feed                             = TC.compute_feed_moles(active_z)
    active_map                              = TC.reduce_kij_map(active_components, KIJ_map)
    
    fig, ax     = TC.plot_PT(PT_results, feed_key, parameters)
    
    bub         = {int(round(pt["T_K"])): float(pt["P_bar"]) for pt in feed.get("bubble", [])}
    dew         = {int(round(pt["T_K"])): float(pt["P_bar"]) for pt in feed.get("dew", [])}
    common_T    = sorted(set(bub) & set(dew))

    # ---- Initialize unified storage for this FIXED feed composition ----
    VLE_DFT[feed_key] = {
        "z": TP_z.tolist(),
        "phase_envelope": {
            "bubble_curve": [{"T_K": T, "P_bar": bub[T]} for T in sorted(bub.keys())],
            "dew_curve": [{"T_K": T, "P_bar": dew[T]} for T in sorted(dew.keys())],
            "isothermal_lines": [
                {"T_K": T, "P_bubble_bar": bub[T], "P_dew_bar": dew[T]} 
                for T in common_T
            ]
        },
        "interfacial_data": {}
    }
    
    if verbose:
        print(f"\n{feed_key}:")
        for T in common_T:
            print(f"  T = {T} K: P_bubble = {bub[T]:.2f} bar, P_dew = {dew[T]:.2f} bar")
    
    if common_T:
        
        for T in common_T:    
            
            # Rebuild parameters and eos at this temperature
            parameters_T        = TC.PARAMETERS(active_components, T_K = float(T), kij_builder = builder, model_map = active_map)
            eos_T               = feos.HelmholtzEnergyFunctional.pcsaft(parameters_T)
            molar_masses        = TC.molar_masses(parameters_T) # g/mol
            
            P_b = bub[T]
            P_d = dew[T]

            if P_b >= P_d:
                
                pressures = np.linspace(P_d + P_TOL, P_b - P_TOL, 10)
                
                # ---- optional: PLOT ----
                ax.plot([T, T], [P_d, P_b], linewidth=0.5, linestyle="--", color="k", alpha=0.3)
                
                # Initialize list for this temperature
                VLE_DFT[feed_key]["interfacial_data"][T] = []
                
                for P in pressures:
                    
                    if verbose:
                        print(f"T = {T} K | P_flash = {P:.2f} | z = {active_z}")
                       
                    # --- TP flash ---
                    try:
                        eq, x, y, liquid_density, vapor_density = TC.tp_flash(
                            feos, eos_T, T*si.KELVIN, P*si.BAR, active_z*si.MOL, molar_masses)
                    except Exception as e:
                        print(f"TP flash failed for z = {active_z} at T = {T} K, P = {P:.2f} bar: {e}")
                        continue
                    
                    # --- planar interface & surface tension ---
                    interface = TC.build_planar_interface(
                        eq, critical_temperature=CT, n_grid=ngrid, l_grid=lgrid)
                    
                    try:
                        gamma_mN_m, interfacial_thickness_nm, enrichment = \
                            TC.solve_interface_properties(interface, si)
                    except Exception as e:
                        print(f"Surface tension calculation failed for z = {active_z} at T = {T} K, P = {P:.2f} bar: {e}")
                        gamma_mN_m = np.nan
                        interfacial_thickness_nm = np.nan
                        enrichment = tuple(np.nan for _ in active_components)
                    
                    if verbose:
                        print(f"T = {T} K | P_flash = {P:.2f} bar | gamma = {gamma_mN_m:.6f} mN/m")

                    row_data = TC.row_append(
                        T_K=float(T),
                        P_bar=float(P),
                        z=active_z,
                        Tc=CT,
                        Pc=CP,
                        P_bubble=P_b,
                        P_dew=P_d,
                        liquid_density=liquid_density,
                        vapor_density=vapor_density,
                        x=x,
                        y=y,
                        gamma_mN_m=gamma_mN_m,
                        interfacial_thickness_nm=interfacial_thickness_nm,
                        components=active_components,
                        enrichment=enrichment,
                        ML_mode=False  # Use only active components
                    )
                    
                    # Store in interfacial_data
                    VLE_DFT[feed_key]["interfacial_data"][T].append(row_data)
                    
    TC.save_plot(fig, f"PT_{feed_key}")
    
    fig_gamma = TC.plot_gamma_colormap(PT_results, VLE_DFT, feed_key, parameters)
    if fig_gamma is not None:
        ps.save_plot(fig_gamma, f"Gamma_{feed_key}")

summary = TC.VLE_DFT_summary(VLE_DFT)

if verbose:
    print(summary)
  
saved_files = TC.VLE_DFT_to_csv(VLE_DFT, verbose=verbose)
# Out:
# feed_1:
#   T = 200 K: P_bubble = 28.80 bar, P_dew = 2.50 bar
#   T = 201 K: P_bubble = 28.72 bar, P_dew = 2.63 bar
#   T = 202 K: P_bubble = 28.64 bar, P_dew = 2.76 bar
#   T = 203 K: P_bubble = 28.58 bar, P_dew = 2.91 bar
#   T = 204 K: P_bubble = 28.53 bar, P_dew = 3.05 bar
#   T = 205 K: P_bubble = 28.50 bar, P_dew = 3.21 bar
#   T = 206 K: P_bubble = 28.47 bar, P_dew = 3.36 bar
#   T = 207 K: P_bubble = 28.45 bar, P_dew = 3.53 bar
#   T = 208 K: P_bubble = 28.44 bar, P_dew = 3.70 bar
#   T = 209 K: P_bubble = 28.45 bar, P_dew = 3.88 bar
#   T = 210 K: P_bubble = 28.46 bar, P_dew = 4.06 bar
#   T = 211 K: P_bubble = 28.49 bar, P_dew = 4.25 bar
#   T = 212 K: P_bubble = 28.52 bar, P_dew = 4.45 bar
#   T = 213 K: P_bubble = 28.57 bar, P_dew = 4.65 bar
#   T = 214 K: P_bubble = 28.62 bar, P_dew = 4.87 bar
#   T = 215 K: P_bubble = 28.69 bar, P_dew = 5.08 bar
#   T = 216 K: P_bubble = 28.76 bar, P_dew = 5.31 bar
#   T = 217 K: P_bubble = 28.85 bar, P_dew = 5.54 bar
#   T = 218 K: P_bubble = 28.95 bar, P_dew = 5.79 bar
#   T = 219 K: P_bubble = 29.06 bar, P_dew = 6.04 bar
#   T = 220 K: P_bubble = 29.17 bar, P_dew = 6.29 bar
#   T = 221 K: P_bubble = 29.30 bar, P_dew = 6.56 bar
#   T = 222 K: P_bubble = 29.44 bar, P_dew = 6.83 bar
#   T = 223 K: P_bubble = 29.59 bar, P_dew = 7.12 bar
#   T = 224 K: P_bubble = 29.75 bar, P_dew = 7.41 bar
#   T = 225 K: P_bubble = 29.92 bar, P_dew = 7.71 bar
#   T = 226 K: P_bubble = 30.11 bar, P_dew = 8.02 bar
#   T = 227 K: P_bubble = 30.30 bar, P_dew = 8.34 bar
#   T = 228 K: P_bubble = 30.50 bar, P_dew = 8.67 bar
#   T = 229 K: P_bubble = 30.72 bar, P_dew = 9.01 bar
#   T = 230 K: P_bubble = 30.94 bar, P_dew = 9.36 bar
#   T = 231 K: P_bubble = 31.18 bar, P_dew = 9.71 bar
#   T = 232 K: P_bubble = 31.43 bar, P_dew = 10.08 bar
#   T = 233 K: P_bubble = 31.69 bar, P_dew = 10.46 bar
#   T = 234 K: P_bubble = 31.96 bar, P_dew = 10.85 bar
#   T = 235 K: P_bubble = 32.24 bar, P_dew = 11.25 bar
#   T = 236 K: P_bubble = 32.54 bar, P_dew = 11.66 bar
#   T = 237 K: P_bubble = 32.84 bar, P_dew = 12.09 bar
#   T = 238 K: P_bubble = 33.16 bar, P_dew = 12.52 bar
#   T = 239 K: P_bubble = 33.49 bar, P_dew = 12.97 bar
#   T = 240 K: P_bubble = 33.83 bar, P_dew = 13.43 bar
#   T = 241 K: P_bubble = 34.19 bar, P_dew = 13.90 bar
#   T = 242 K: P_bubble = 34.55 bar, P_dew = 14.38 bar
#   T = 243 K: P_bubble = 34.93 bar, P_dew = 14.87 bar
#   T = 244 K: P_bubble = 35.33 bar, P_dew = 15.38 bar
#   T = 245 K: P_bubble = 35.73 bar, P_dew = 15.90 bar
#   T = 246 K: P_bubble = 36.15 bar, P_dew = 16.44 bar
#   T = 247 K: P_bubble = 36.58 bar, P_dew = 16.98 bar
#   T = 248 K: P_bubble = 37.02 bar, P_dew = 17.54 bar
#   T = 249 K: P_bubble = 37.48 bar, P_dew = 18.12 bar
#   T = 250 K: P_bubble = 37.94 bar, P_dew = 18.71 bar
#   T = 251 K: P_bubble = 38.43 bar, P_dew = 19.31 bar
#   T = 252 K: P_bubble = 38.92 bar, P_dew = 19.93 bar
#   T = 253 K: P_bubble = 39.43 bar, P_dew = 20.56 bar
#   T = 254 K: P_bubble = 39.96 bar, P_dew = 21.21 bar
#   T = 255 K: P_bubble = 40.50 bar, P_dew = 21.87 bar
#   T = 256 K: P_bubble = 41.05 bar, P_dew = 22.55 bar
#   T = 257 K: P_bubble = 41.61 bar, P_dew = 23.24 bar
#   T = 258 K: P_bubble = 42.19 bar, P_dew = 23.95 bar
#   T = 259 K: P_bubble = 42.79 bar, P_dew = 24.67 bar
#   T = 260 K: P_bubble = 43.40 bar, P_dew = 25.42 bar
#   T = 261 K: P_bubble = 44.02 bar, P_dew = 26.17 bar
#   T = 262 K: P_bubble = 44.66 bar, P_dew = 26.95 bar
#   T = 263 K: P_bubble = 45.32 bar, P_dew = 27.74 bar
#   T = 264 K: P_bubble = 45.99 bar, P_dew = 28.55 bar
#   T = 265 K: P_bubble = 46.67 bar, P_dew = 29.38 bar
#   T = 266 K: P_bubble = 47.37 bar, P_dew = 30.23 bar
#   T = 267 K: P_bubble = 48.09 bar, P_dew = 31.09 bar
#   T = 268 K: P_bubble = 48.82 bar, P_dew = 31.98 bar
#   T = 269 K: P_bubble = 49.57 bar, P_dew = 32.88 bar
#   T = 270 K: P_bubble = 50.33 bar, P_dew = 33.80 bar
#   T = 271 K: P_bubble = 51.11 bar, P_dew = 34.75 bar
#   T = 272 K: P_bubble = 51.91 bar, P_dew = 35.71 bar
#   T = 273 K: P_bubble = 52.72 bar, P_dew = 36.69 bar
#   T = 274 K: P_bubble = 53.55 bar, P_dew = 37.69 bar
#   T = 275 K: P_bubble = 54.39 bar, P_dew = 38.72 bar
#   T = 276 K: P_bubble = 55.26 bar, P_dew = 39.77 bar
#   T = 277 K: P_bubble = 56.14 bar, P_dew = 40.83 bar
#   T = 278 K: P_bubble = 57.03 bar, P_dew = 41.93 bar
#   T = 279 K: P_bubble = 57.95 bar, P_dew = 43.04 bar
#   T = 280 K: P_bubble = 58.88 bar, P_dew = 44.18 bar
#   T = 281 K: P_bubble = 59.82 bar, P_dew = 45.34 bar
#   T = 282 K: P_bubble = 60.79 bar, P_dew = 46.52 bar
#   T = 283 K: P_bubble = 61.77 bar, P_dew = 47.73 bar
#   T = 284 K: P_bubble = 62.77 bar, P_dew = 48.97 bar
#   T = 285 K: P_bubble = 63.78 bar, P_dew = 50.23 bar
#   T = 286 K: P_bubble = 64.82 bar, P_dew = 51.52 bar
#   T = 287 K: P_bubble = 65.87 bar, P_dew = 52.83 bar
#   T = 288 K: P_bubble = 66.94 bar, P_dew = 54.18 bar
#   T = 289 K: P_bubble = 68.02 bar, P_dew = 55.55 bar
#   T = 290 K: P_bubble = 69.12 bar, P_dew = 56.95 bar
#   T = 291 K: P_bubble = 70.24 bar, P_dew = 58.39 bar
#   T = 292 K: P_bubble = 71.37 bar, P_dew = 59.85 bar
#   T = 293 K: P_bubble = 72.52 bar, P_dew = 61.35 bar
#   T = 294 K: P_bubble = 73.68 bar, P_dew = 62.88 bar
#   T = 295 K: P_bubble = 74.86 bar, P_dew = 64.45 bar
#   T = 296 K: P_bubble = 76.05 bar, P_dew = 66.06 bar
#   T = 297 K: P_bubble = 77.24 bar, P_dew = 67.71 bar
#   T = 298 K: P_bubble = 78.45 bar, P_dew = 69.40 bar
#   T = 302 K: P_bubble = 83.30 bar, P_dew = 83.30 bar
# T = 200 K | P_flash = 2.50 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 200 K | P_flash = 2.50 bar | gamma = 19.876182 mN/m
# T = 200 K | P_flash = 5.42 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 200 K | P_flash = 5.42 bar | gamma = 18.925810 mN/m
# T = 200 K | P_flash = 8.34 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 200 K | P_flash = 8.34 bar | gamma = 18.103216 mN/m
# T = 200 K | P_flash = 11.26 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 200 K | P_flash = 11.26 bar | gamma = 17.392324 mN/m
# T = 200 K | P_flash = 14.19 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 200 K | P_flash = 14.19 bar | gamma = 16.790165 mN/m
# T = 200 K | P_flash = 17.11 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 200 K | P_flash = 17.11 bar | gamma = 16.298989 mN/m
# T = 200 K | P_flash = 20.03 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 200 K | P_flash = 20.03 bar | gamma = 15.913760 mN/m
# T = 200 K | P_flash = 22.95 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 200 K | P_flash = 22.95 bar | gamma = 15.615803 mN/m
# T = 200 K | P_flash = 25.88 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 200 K | P_flash = 25.88 bar | gamma = 15.380303 mN/m
# T = 200 K | P_flash = 28.80 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 200 K | P_flash = 28.80 bar | gamma = 15.186230 mN/m
# T = 201 K | P_flash = 2.63 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 201 K | P_flash = 2.63 bar | gamma = 19.638799 mN/m
# T = 201 K | P_flash = 5.53 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 201 K | P_flash = 5.53 bar | gamma = 18.716810 mN/m
# T = 201 K | P_flash = 8.42 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 201 K | P_flash = 8.42 bar | gamma = 17.915960 mN/m
# T = 201 K | P_flash = 11.32 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 201 K | P_flash = 11.32 bar | gamma = 17.221431 mN/m
# T = 201 K | P_flash = 14.22 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 201 K | P_flash = 14.22 bar | gamma = 16.630577 mN/m
# T = 201 K | P_flash = 17.12 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 201 K | P_flash = 17.12 bar | gamma = 16.145899 mN/m
# T = 201 K | P_flash = 20.02 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 201 K | P_flash = 20.02 bar | gamma = 15.763504 mN/m
# T = 201 K | P_flash = 22.92 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 201 K | P_flash = 22.92 bar | gamma = 15.466537 mN/m
# T = 201 K | P_flash = 25.82 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 201 K | P_flash = 25.82 bar | gamma = 15.231520 mN/m
# T = 201 K | P_flash = 28.72 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 201 K | P_flash = 28.72 bar | gamma = 15.037959 mN/m
# T = 202 K | P_flash = 2.76 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 202 K | P_flash = 2.76 bar | gamma = 19.401924 mN/m
# T = 202 K | P_flash = 5.64 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 202 K | P_flash = 5.64 bar | gamma = 18.507208 mN/m
# T = 202 K | P_flash = 8.51 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 202 K | P_flash = 8.51 bar | gamma = 17.727396 mN/m
# T = 202 K | P_flash = 11.39 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 202 K | P_flash = 11.39 bar | gamma = 17.048824 mN/m
# T = 202 K | P_flash = 14.27 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 202 K | P_flash = 14.27 bar | gamma = 16.469136 mN/m
# T = 202 K | P_flash = 17.14 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 202 K | P_flash = 17.14 bar | gamma = 15.991026 mN/m
# T = 202 K | P_flash = 20.02 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 202 K | P_flash = 20.02 bar | gamma = 15.611614 mN/m
# T = 202 K | P_flash = 22.89 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 202 K | P_flash = 22.89 bar | gamma = 15.315740 mN/m
# T = 202 K | P_flash = 25.77 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 202 K | P_flash = 25.77 bar | gamma = 15.081248 mN/m
# T = 202 K | P_flash = 28.64 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 202 K | P_flash = 28.64 bar | gamma = 14.888222 mN/m
# T = 203 K | P_flash = 2.91 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 203 K | P_flash = 2.91 bar | gamma = 19.165561 mN/m
# T = 203 K | P_flash = 5.76 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 203 K | P_flash = 5.76 bar | gamma = 18.297062 mN/m
# T = 203 K | P_flash = 8.61 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 203 K | P_flash = 8.61 bar | gamma = 17.537610 mN/m
# T = 203 K | P_flash = 11.46 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 203 K | P_flash = 11.46 bar | gamma = 16.874596 mN/m
# T = 203 K | P_flash = 14.32 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 203 K | P_flash = 14.32 bar | gamma = 16.305927 mN/m
# T = 203 K | P_flash = 17.17 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 203 K | P_flash = 17.17 bar | gamma = 15.834444 mN/m
# T = 203 K | P_flash = 20.02 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 203 K | P_flash = 20.02 bar | gamma = 15.458151 mN/m
# T = 203 K | P_flash = 22.88 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 203 K | P_flash = 22.88 bar | gamma = 15.163473 mN/m
# T = 203 K | P_flash = 25.73 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 203 K | P_flash = 25.73 bar | gamma = 14.929553 mN/m
# T = 203 K | P_flash = 28.58 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 203 K | P_flash = 28.58 bar | gamma = 14.737055 mN/m
# T = 204 K | P_flash = 3.05 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 204 K | P_flash = 3.05 bar | gamma = 18.929716 mN/m
# T = 204 K | P_flash = 5.88 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 204 K | P_flash = 5.88 bar | gamma = 18.086430 mN/m
# T = 204 K | P_flash = 8.72 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 204 K | P_flash = 8.72 bar | gamma = 17.346685 mN/m
# T = 204 K | P_flash = 11.55 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 204 K | P_flash = 11.55 bar | gamma = 16.698840 mN/m
# T = 204 K | P_flash = 14.38 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 204 K | P_flash = 14.38 bar | gamma = 16.141037 mN/m
# T = 204 K | P_flash = 17.21 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 204 K | P_flash = 17.21 bar | gamma = 15.676222 mN/m
# T = 204 K | P_flash = 20.04 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 204 K | P_flash = 20.04 bar | gamma = 15.303178 mN/m
# T = 204 K | P_flash = 22.87 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 204 K | P_flash = 22.87 bar | gamma = 15.009798 mN/m
# T = 204 K | P_flash = 25.70 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 204 K | P_flash = 25.70 bar | gamma = 14.776494 mN/m
# T = 204 K | P_flash = 28.53 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 204 K | P_flash = 28.53 bar | gamma = 14.584551 mN/m
# T = 205 K | P_flash = 3.21 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 205 K | P_flash = 3.21 bar | gamma = 18.694393 mN/m
# T = 205 K | P_flash = 6.02 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 205 K | P_flash = 6.02 bar | gamma = 17.875367 mN/m
# T = 205 K | P_flash = 8.83 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 205 K | P_flash = 8.83 bar | gamma = 17.154699 mN/m
# T = 205 K | P_flash = 11.64 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 205 K | P_flash = 11.64 bar | gamma = 16.521642 mN/m
# T = 205 K | P_flash = 14.45 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 205 K | P_flash = 14.45 bar | gamma = 15.974546 mN/m
# T = 205 K | P_flash = 17.26 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 205 K | P_flash = 17.26 bar | gamma = 15.516432 mN/m
# T = 205 K | P_flash = 20.07 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 205 K | P_flash = 20.07 bar | gamma = 15.146755 mN/m
# T = 205 K | P_flash = 22.88 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 205 K | P_flash = 22.88 bar | gamma = 14.854771 mN/m
# T = 205 K | P_flash = 25.69 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 205 K | P_flash = 25.69 bar | gamma = 14.622133 mN/m
# T = 205 K | P_flash = 28.50 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 205 K | P_flash = 28.50 bar | gamma = 14.430749 mN/m
# T = 206 K | P_flash = 3.36 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 206 K | P_flash = 3.36 bar | gamma = 18.459597 mN/m
# T = 206 K | P_flash = 6.15 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 206 K | P_flash = 6.15 bar | gamma = 17.663922 mN/m
# T = 206 K | P_flash = 8.94 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 206 K | P_flash = 8.94 bar | gamma = 16.961729 mN/m
# T = 206 K | P_flash = 11.73 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 206 K | P_flash = 11.73 bar | gamma = 16.343086 mN/m
# T = 206 K | P_flash = 14.52 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 206 K | P_flash = 14.52 bar | gamma = 15.806536 mN/m
# T = 206 K | P_flash = 17.31 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 206 K | P_flash = 17.31 bar | gamma = 15.355140 mN/m
# T = 206 K | P_flash = 20.10 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 206 K | P_flash = 20.10 bar | gamma = 14.988940 mN/m
# T = 206 K | P_flash = 22.89 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 206 K | P_flash = 22.89 bar | gamma = 14.698451 mN/m
# T = 206 K | P_flash = 25.68 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 206 K | P_flash = 25.68 bar | gamma = 14.466526 mN/m
# T = 206 K | P_flash = 28.47 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 206 K | P_flash = 28.47 bar | gamma = 14.275706 mN/m
# T = 207 K | P_flash = 3.53 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 207 K | P_flash = 3.53 bar | gamma = 18.225333 mN/m
# T = 207 K | P_flash = 6.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 207 K | P_flash = 6.30 bar | gamma = 17.452145 mN/m
# T = 207 K | P_flash = 9.07 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 207 K | P_flash = 9.07 bar | gamma = 16.767846 mN/m
# T = 207 K | P_flash = 11.84 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 207 K | P_flash = 11.84 bar | gamma = 16.163254 mN/m
# T = 207 K | P_flash = 14.61 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 207 K | P_flash = 14.61 bar | gamma = 15.637083 mN/m
# T = 207 K | P_flash = 17.37 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 207 K | P_flash = 17.37 bar | gamma = 15.192415 mN/m
# T = 207 K | P_flash = 20.14 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 207 K | P_flash = 20.14 bar | gamma = 14.829793 mN/m
# T = 207 K | P_flash = 22.91 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 207 K | P_flash = 22.91 bar | gamma = 14.540892 mN/m
# T = 207 K | P_flash = 25.68 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 207 K | P_flash = 25.68 bar | gamma = 14.309730 mN/m
# T = 207 K | P_flash = 28.45 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 207 K | P_flash = 28.45 bar | gamma = 14.119500 mN/m
# T = 208 K | P_flash = 3.70 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 208 K | P_flash = 3.70 bar | gamma = 17.991607 mN/m
# T = 208 K | P_flash = 6.45 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 208 K | P_flash = 6.45 bar | gamma = 17.240084 mN/m
# T = 208 K | P_flash = 9.20 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 208 K | P_flash = 9.20 bar | gamma = 16.573119 mN/m
# T = 208 K | P_flash = 11.95 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 208 K | P_flash = 11.95 bar | gamma = 15.982223 mN/m
# T = 208 K | P_flash = 14.70 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 208 K | P_flash = 14.70 bar | gamma = 15.466265 mN/m
# T = 208 K | P_flash = 17.45 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 208 K | P_flash = 17.45 bar | gamma = 15.028323 mN/m
# T = 208 K | P_flash = 20.20 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 208 K | P_flash = 20.20 bar | gamma = 14.669371 mN/m
# T = 208 K | P_flash = 22.95 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 208 K | P_flash = 22.95 bar | gamma = 14.382142 mN/m
# T = 208 K | P_flash = 25.69 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 208 K | P_flash = 25.69 bar | gamma = 14.151801 mN/m
# T = 208 K | P_flash = 28.44 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 208 K | P_flash = 28.44 bar | gamma = 13.962175 mN/m
# T = 209 K | P_flash = 3.88 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 209 K | P_flash = 3.88 bar | gamma = 17.758423 mN/m
# T = 209 K | P_flash = 6.61 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 209 K | P_flash = 6.61 bar | gamma = 17.027782 mN/m
# T = 209 K | P_flash = 9.34 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 209 K | P_flash = 9.34 bar | gamma = 16.377615 mN/m
# T = 209 K | P_flash = 12.07 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 209 K | P_flash = 12.07 bar | gamma = 15.800069 mN/m
# T = 209 K | P_flash = 14.80 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 209 K | P_flash = 14.80 bar | gamma = 15.294154 mN/m
# T = 209 K | P_flash = 17.53 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 209 K | P_flash = 17.53 bar | gamma = 14.862927 mN/m
# T = 209 K | P_flash = 20.26 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 209 K | P_flash = 20.26 bar | gamma = 14.507729 mN/m
# T = 209 K | P_flash = 22.99 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 209 K | P_flash = 22.99 bar | gamma = 14.222269 mN/m
# T = 209 K | P_flash = 25.72 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 209 K | P_flash = 25.72 bar | gamma = 13.992792 mN/m
# T = 209 K | P_flash = 28.45 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 209 K | P_flash = 28.45 bar | gamma = 13.803789 mN/m
# T = 210 K | P_flash = 4.06 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 210 K | P_flash = 4.06 bar | gamma = 17.525788 mN/m
# T = 210 K | P_flash = 6.77 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 210 K | P_flash = 6.77 bar | gamma = 16.815281 mN/m
# T = 210 K | P_flash = 9.48 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 210 K | P_flash = 9.48 bar | gamma = 16.181396 mN/m
# T = 210 K | P_flash = 12.20 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 210 K | P_flash = 12.20 bar | gamma = 15.616864 mN/m
# T = 210 K | P_flash = 14.91 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 210 K | P_flash = 14.91 bar | gamma = 15.120821 mN/m
# T = 210 K | P_flash = 17.62 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 210 K | P_flash = 17.62 bar | gamma = 14.696291 mN/m
# T = 210 K | P_flash = 20.33 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 210 K | P_flash = 20.33 bar | gamma = 14.344922 mN/m
# T = 210 K | P_flash = 23.04 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 210 K | P_flash = 23.04 bar | gamma = 14.061318 mN/m
# T = 210 K | P_flash = 25.75 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 210 K | P_flash = 25.75 bar | gamma = 13.832756 mN/m
# T = 210 K | P_flash = 28.46 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 210 K | P_flash = 28.46 bar | gamma = 13.644394 mN/m
# T = 211 K | P_flash = 4.25 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 211 K | P_flash = 4.25 bar | gamma = 17.293707 mN/m
# T = 211 K | P_flash = 6.95 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 211 K | P_flash = 6.95 bar | gamma = 16.602624 mN/m
# T = 211 K | P_flash = 9.64 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 211 K | P_flash = 9.64 bar | gamma = 15.984523 mN/m
# T = 211 K | P_flash = 12.33 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 211 K | P_flash = 12.33 bar | gamma = 15.432678 mN/m
# T = 211 K | P_flash = 15.02 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 211 K | P_flash = 15.02 bar | gamma = 14.946338 mN/m
# T = 211 K | P_flash = 17.72 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 211 K | P_flash = 17.72 bar | gamma = 14.528477 mN/m
# T = 211 K | P_flash = 20.41 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 211 K | P_flash = 20.41 bar | gamma = 14.181006 mN/m
# T = 211 K | P_flash = 23.10 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 211 K | P_flash = 23.10 bar | gamma = 13.899339 mN/m
# T = 211 K | P_flash = 25.79 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 211 K | P_flash = 25.79 bar | gamma = 13.671744 mN/m
# T = 211 K | P_flash = 28.49 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 211 K | P_flash = 28.49 bar | gamma = 13.484043 mN/m
# T = 212 K | P_flash = 4.45 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 212 K | P_flash = 4.45 bar | gamma = 17.062186 mN/m
# T = 212 K | P_flash = 7.12 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 212 K | P_flash = 7.12 bar | gamma = 16.389848 mN/m
# T = 212 K | P_flash = 9.80 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 212 K | P_flash = 9.80 bar | gamma = 15.787054 mN/m
# T = 212 K | P_flash = 12.47 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 212 K | P_flash = 12.47 bar | gamma = 15.247578 mN/m
# T = 212 K | P_flash = 15.15 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 212 K | P_flash = 15.15 bar | gamma = 14.770768 mN/m
# T = 212 K | P_flash = 17.82 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 212 K | P_flash = 17.82 bar | gamma = 14.359545 mN/m
# T = 212 K | P_flash = 20.50 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 212 K | P_flash = 20.50 bar | gamma = 14.016033 mN/m
# T = 212 K | P_flash = 23.17 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 212 K | P_flash = 23.17 bar | gamma = 13.736383 mN/m
# T = 212 K | P_flash = 25.85 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 212 K | P_flash = 25.85 bar | gamma = 13.509806 mN/m
# T = 212 K | P_flash = 28.52 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 212 K | P_flash = 28.52 bar | gamma = 13.322787 mN/m
# T = 213 K | P_flash = 4.65 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 213 K | P_flash = 4.65 bar | gamma = 16.831230 mN/m
# T = 213 K | P_flash = 7.31 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 213 K | P_flash = 7.31 bar | gamma = 16.176991 mN/m
# T = 213 K | P_flash = 9.97 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 213 K | P_flash = 9.97 bar | gamma = 15.589046 mN/m
# T = 213 K | P_flash = 12.63 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 213 K | P_flash = 12.63 bar | gamma = 15.061628 mN/m
# T = 213 K | P_flash = 15.28 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 213 K | P_flash = 15.28 bar | gamma = 14.594178 mN/m
# T = 213 K | P_flash = 17.94 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 213 K | P_flash = 17.94 bar | gamma = 14.189556 mN/m
# T = 213 K | P_flash = 20.60 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 213 K | P_flash = 20.60 bar | gamma = 13.850055 mN/m
# T = 213 K | P_flash = 23.25 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 213 K | P_flash = 23.25 bar | gamma = 13.572497 mN/m
# T = 213 K | P_flash = 25.91 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 213 K | P_flash = 25.91 bar | gamma = 13.346982 mN/m
# T = 213 K | P_flash = 28.57 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 213 K | P_flash = 28.57 bar | gamma = 13.160675 mN/m
# T = 214 K | P_flash = 4.87 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 214 K | P_flash = 4.87 bar | gamma = 16.600847 mN/m
# T = 214 K | P_flash = 7.51 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 214 K | P_flash = 7.51 bar | gamma = 15.964088 mN/m
# T = 214 K | P_flash = 10.15 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 214 K | P_flash = 10.15 bar | gamma = 15.390550 mN/m
# T = 214 K | P_flash = 12.78 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 214 K | P_flash = 12.78 bar | gamma = 14.874890 mN/m
# T = 214 K | P_flash = 15.42 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 214 K | P_flash = 15.42 bar | gamma = 14.416632 mN/m
# T = 214 K | P_flash = 18.06 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 214 K | P_flash = 18.06 bar | gamma = 14.018566 mN/m
# T = 214 K | P_flash = 20.70 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 214 K | P_flash = 20.70 bar | gamma = 13.683124 mN/m
# T = 214 K | P_flash = 23.34 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 214 K | P_flash = 23.34 bar | gamma = 13.407730 mN/m
# T = 214 K | P_flash = 25.98 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 214 K | P_flash = 25.98 bar | gamma = 13.183336 mN/m
# T = 214 K | P_flash = 28.62 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 214 K | P_flash = 28.62 bar | gamma = 12.997755 mN/m
# T = 215 K | P_flash = 5.08 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 215 K | P_flash = 5.08 bar | gamma = 16.371041 mN/m
# T = 215 K | P_flash = 7.71 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 215 K | P_flash = 7.71 bar | gamma = 15.751175 mN/m
# T = 215 K | P_flash = 10.33 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 215 K | P_flash = 10.33 bar | gamma = 15.191620 mN/m
# T = 215 K | P_flash = 12.95 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 215 K | P_flash = 12.95 bar | gamma = 14.687425 mN/m
# T = 215 K | P_flash = 15.57 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 215 K | P_flash = 15.57 bar | gamma = 14.238190 mN/m
# T = 215 K | P_flash = 18.20 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 215 K | P_flash = 18.20 bar | gamma = 13.846633 mN/m
# T = 215 K | P_flash = 20.82 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 215 K | P_flash = 20.82 bar | gamma = 13.515289 mN/m
# T = 215 K | P_flash = 23.44 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 215 K | P_flash = 23.44 bar | gamma = 13.242129 mN/m
# T = 215 K | P_flash = 26.06 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 215 K | P_flash = 26.06 bar | gamma = 13.018906 mN/m
# T = 215 K | P_flash = 28.69 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 215 K | P_flash = 28.69 bar | gamma = 12.834076 mN/m
# T = 216 K | P_flash = 5.31 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 216 K | P_flash = 5.31 bar | gamma = 16.141821 mN/m
# T = 216 K | P_flash = 7.92 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 216 K | P_flash = 7.92 bar | gamma = 15.538284 mN/m
# T = 216 K | P_flash = 10.52 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 216 K | P_flash = 10.52 bar | gamma = 14.992303 mN/m
# T = 216 K | P_flash = 13.13 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 216 K | P_flash = 13.13 bar | gamma = 14.499291 mN/m
# T = 216 K | P_flash = 15.73 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 216 K | P_flash = 15.73 bar | gamma = 14.058913 mN/m
# T = 216 K | P_flash = 18.34 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 216 K | P_flash = 18.34 bar | gamma = 13.673812 mN/m
# T = 216 K | P_flash = 20.95 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 216 K | P_flash = 20.95 bar | gamma = 13.346601 mN/m
# T = 216 K | P_flash = 23.55 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 216 K | P_flash = 23.55 bar | gamma = 13.075739 mN/m
# T = 216 K | P_flash = 26.16 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 216 K | P_flash = 26.16 bar | gamma = 12.853737 mN/m
# T = 216 K | P_flash = 28.76 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 216 K | P_flash = 28.76 bar | gamma = 12.669683 mN/m
# T = 217 K | P_flash = 5.54 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 217 K | P_flash = 5.54 bar | gamma = 15.913192 mN/m
# T = 217 K | P_flash = 8.13 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 217 K | P_flash = 8.13 bar | gamma = 15.325447 mN/m
# T = 217 K | P_flash = 10.72 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 217 K | P_flash = 10.72 bar | gamma = 14.792648 mN/m
# T = 217 K | P_flash = 13.31 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 217 K | P_flash = 13.31 bar | gamma = 14.310543 mN/m
# T = 217 K | P_flash = 15.90 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 217 K | P_flash = 15.90 bar | gamma = 13.878858 mN/m
# T = 217 K | P_flash = 18.49 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 217 K | P_flash = 18.49 bar | gamma = 13.500157 mN/m
# T = 217 K | P_flash = 21.08 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 217 K | P_flash = 21.08 bar | gamma = 13.177108 mN/m
# T = 217 K | P_flash = 23.67 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 217 K | P_flash = 23.67 bar | gamma = 12.908606 mN/m
# T = 217 K | P_flash = 26.26 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 217 K | P_flash = 26.26 bar | gamma = 12.687875 mN/m
# T = 217 K | P_flash = 28.85 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 217 K | P_flash = 28.85 bar | gamma = 12.504621 mN/m
# T = 218 K | P_flash = 5.79 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 218 K | P_flash = 5.79 bar | gamma = 15.685161 mN/m
# T = 218 K | P_flash = 8.36 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 218 K | P_flash = 8.36 bar | gamma = 15.112696 mN/m
# T = 218 K | P_flash = 10.93 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 218 K | P_flash = 10.93 bar | gamma = 14.592700 mN/m
# T = 218 K | P_flash = 13.51 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 218 K | P_flash = 13.51 bar | gamma = 14.121236 mN/m
# T = 218 K | P_flash = 16.08 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 218 K | P_flash = 16.08 bar | gamma = 13.698082 mN/m
# T = 218 K | P_flash = 18.65 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 218 K | P_flash = 18.65 bar | gamma = 13.325722 mN/m
# T = 218 K | P_flash = 21.23 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 218 K | P_flash = 21.23 bar | gamma = 13.006857 mN/m
# T = 218 K | P_flash = 23.80 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 218 K | P_flash = 23.80 bar | gamma = 12.740773 mN/m
# T = 218 K | P_flash = 26.37 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 218 K | P_flash = 26.37 bar | gamma = 12.521362 mN/m
# T = 218 K | P_flash = 28.95 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 218 K | P_flash = 28.95 bar | gamma = 12.338934 mN/m
# T = 219 K | P_flash = 6.04 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 219 K | P_flash = 6.04 bar | gamma = 15.457735 mN/m
# T = 219 K | P_flash = 8.59 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 219 K | P_flash = 8.59 bar | gamma = 14.900058 mN/m
# T = 219 K | P_flash = 11.15 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 219 K | P_flash = 11.15 bar | gamma = 14.392503 mN/m
# T = 219 K | P_flash = 13.71 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 219 K | P_flash = 13.71 bar | gamma = 13.931421 mN/m
# T = 219 K | P_flash = 16.27 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 219 K | P_flash = 16.27 bar | gamma = 13.516638 mN/m
# T = 219 K | P_flash = 18.82 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 219 K | P_flash = 18.82 bar | gamma = 13.150557 mN/m
# T = 219 K | P_flash = 21.38 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 219 K | P_flash = 21.38 bar | gamma = 12.835895 mN/m
# T = 219 K | P_flash = 23.94 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 219 K | P_flash = 23.94 bar | gamma = 12.572284 mN/m
# T = 219 K | P_flash = 26.50 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 219 K | P_flash = 26.50 bar | gamma = 12.354242 mN/m
# T = 219 K | P_flash = 29.06 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 219 K | P_flash = 29.06 bar | gamma = 12.172666 mN/m
# T = 220 K | P_flash = 6.29 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 220 K | P_flash = 6.29 bar | gamma = 15.230922 mN/m
# T = 220 K | P_flash = 8.84 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 220 K | P_flash = 8.84 bar | gamma = 14.687564 mN/m
# T = 220 K | P_flash = 11.38 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 220 K | P_flash = 11.38 bar | gamma = 14.192101 mN/m
# T = 220 K | P_flash = 13.92 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 220 K | P_flash = 13.92 bar | gamma = 13.741149 mN/m
# T = 220 K | P_flash = 16.46 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 220 K | P_flash = 16.46 bar | gamma = 13.334580 mN/m
# T = 220 K | P_flash = 19.00 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 220 K | P_flash = 19.00 bar | gamma = 12.974714 mN/m
# T = 220 K | P_flash = 21.55 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 220 K | P_flash = 21.55 bar | gamma = 12.664269 mN/m
# T = 220 K | P_flash = 24.09 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 220 K | P_flash = 24.09 bar | gamma = 12.403182 mN/m
# T = 220 K | P_flash = 26.63 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 220 K | P_flash = 26.63 bar | gamma = 12.186556 mN/m
# T = 220 K | P_flash = 29.17 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 220 K | P_flash = 29.17 bar | gamma = 12.005859 mN/m
# T = 221 K | P_flash = 6.56 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 221 K | P_flash = 6.56 bar | gamma = 15.004729 mN/m
# T = 221 K | P_flash = 9.09 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 221 K | P_flash = 9.09 bar | gamma = 14.475241 mN/m
# T = 221 K | P_flash = 11.61 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 221 K | P_flash = 11.61 bar | gamma = 13.991533 mN/m
# T = 221 K | P_flash = 14.14 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 221 K | P_flash = 14.14 bar | gamma = 13.550468 mN/m
# T = 221 K | P_flash = 16.67 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 221 K | P_flash = 16.67 bar | gamma = 13.151959 mN/m
# T = 221 K | P_flash = 19.19 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 221 K | P_flash = 19.19 bar | gamma = 12.798242 mN/m
# T = 221 K | P_flash = 21.72 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 221 K | P_flash = 21.72 bar | gamma = 12.492023 mN/m
# T = 221 K | P_flash = 24.25 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 221 K | P_flash = 24.25 bar | gamma = 12.233508 mN/m
# T = 221 K | P_flash = 26.78 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 221 K | P_flash = 26.78 bar | gamma = 12.018344 mN/m
# T = 221 K | P_flash = 29.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 221 K | P_flash = 29.30 bar | gamma = 11.838554 mN/m
# T = 222 K | P_flash = 6.83 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 222 K | P_flash = 6.83 bar | gamma = 14.779163 mN/m
# T = 222 K | P_flash = 9.35 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 222 K | P_flash = 9.35 bar | gamma = 14.263116 mN/m
# T = 222 K | P_flash = 11.86 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 222 K | P_flash = 11.86 bar | gamma = 13.790839 mN/m
# T = 222 K | P_flash = 14.37 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 222 K | P_flash = 14.37 bar | gamma = 13.359427 mN/m
# T = 222 K | P_flash = 16.88 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 222 K | P_flash = 16.88 bar | gamma = 12.968825 mN/m
# T = 222 K | P_flash = 19.39 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 222 K | P_flash = 19.39 bar | gamma = 12.621190 mN/m
# T = 222 K | P_flash = 21.91 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 222 K | P_flash = 21.91 bar | gamma = 12.319202 mN/m
# T = 222 K | P_flash = 24.42 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 222 K | P_flash = 24.42 bar | gamma = 12.063303 mN/m
# T = 222 K | P_flash = 26.93 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 222 K | P_flash = 26.93 bar | gamma = 11.849647 mN/m
# T = 222 K | P_flash = 29.44 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 222 K | P_flash = 29.44 bar | gamma = 11.670791 mN/m
# T = 223 K | P_flash = 7.12 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 223 K | P_flash = 7.12 bar | gamma = 14.554231 mN/m
# T = 223 K | P_flash = 9.61 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 223 K | P_flash = 9.61 bar | gamma = 14.051215 mN/m
# T = 223 K | P_flash = 12.11 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 223 K | P_flash = 12.11 bar | gamma = 13.590058 mN/m
# T = 223 K | P_flash = 14.61 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 223 K | P_flash = 14.61 bar | gamma = 13.168070 mN/m
# T = 223 K | P_flash = 17.11 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 223 K | P_flash = 17.11 bar | gamma = 12.785226 mN/m
# T = 223 K | P_flash = 19.60 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 223 K | P_flash = 19.60 bar | gamma = 12.443604 mN/m
# T = 223 K | P_flash = 22.10 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 223 K | P_flash = 22.10 bar | gamma = 12.145850 mN/m
# T = 223 K | P_flash = 24.60 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 223 K | P_flash = 24.60 bar | gamma = 11.892609 mN/m
# T = 223 K | P_flash = 27.09 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 223 K | P_flash = 27.09 bar | gamma = 11.680505 mN/m
# T = 223 K | P_flash = 29.59 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 223 K | P_flash = 29.59 bar | gamma = 11.502612 mN/m
# T = 224 K | P_flash = 7.41 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 224 K | P_flash = 7.41 bar | gamma = 14.329943 mN/m
# T = 224 K | P_flash = 9.89 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 224 K | P_flash = 9.89 bar | gamma = 13.839563 mN/m
# T = 224 K | P_flash = 12.37 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 224 K | P_flash = 12.37 bar | gamma = 13.389228 mN/m
# T = 224 K | P_flash = 14.86 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 224 K | P_flash = 14.86 bar | gamma = 12.976442 mN/m
# T = 224 K | P_flash = 17.34 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 224 K | P_flash = 17.34 bar | gamma = 12.601210 mN/m
# T = 224 K | P_flash = 19.82 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 224 K | P_flash = 19.82 bar | gamma = 12.265532 mN/m
# T = 224 K | P_flash = 22.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 224 K | P_flash = 22.30 bar | gamma = 11.972008 mN/m
# T = 224 K | P_flash = 24.79 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 224 K | P_flash = 24.79 bar | gamma = 11.721464 mN/m
# T = 224 K | P_flash = 27.27 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 224 K | P_flash = 27.27 bar | gamma = 11.510955 mN/m
# T = 224 K | P_flash = 29.75 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 224 K | P_flash = 29.75 bar | gamma = 11.334054 mN/m
# T = 225 K | P_flash = 7.71 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 225 K | P_flash = 7.71 bar | gamma = 14.106306 mN/m
# T = 225 K | P_flash = 10.18 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 225 K | P_flash = 10.18 bar | gamma = 13.628186 mN/m
# T = 225 K | P_flash = 12.65 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 225 K | P_flash = 12.65 bar | gamma = 13.188383 mN/m
# T = 225 K | P_flash = 15.11 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 225 K | P_flash = 15.11 bar | gamma = 12.784586 mN/m
# T = 225 K | P_flash = 17.58 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 225 K | P_flash = 17.58 bar | gamma = 12.416823 mN/m
# T = 225 K | P_flash = 20.05 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 225 K | P_flash = 20.05 bar | gamma = 12.087017 mN/m
# T = 225 K | P_flash = 22.52 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 225 K | P_flash = 22.52 bar | gamma = 11.797720 mN/m
# T = 225 K | P_flash = 24.99 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 225 K | P_flash = 24.99 bar | gamma = 11.549908 mN/m
# T = 225 K | P_flash = 27.46 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 225 K | P_flash = 27.46 bar | gamma = 11.341037 mN/m
# T = 225 K | P_flash = 29.92 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 225 K | P_flash = 29.92 bar | gamma = 11.165154 mN/m
# T = 226 K | P_flash = 8.02 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 226 K | P_flash = 8.02 bar | gamma = 13.883328 mN/m
# T = 226 K | P_flash = 10.47 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 226 K | P_flash = 10.47 bar | gamma = 13.417108 mN/m
# T = 226 K | P_flash = 12.93 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 226 K | P_flash = 12.93 bar | gamma = 12.987560 mN/m
# T = 226 K | P_flash = 15.38 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 226 K | P_flash = 15.38 bar | gamma = 12.592544 mN/m
# T = 226 K | P_flash = 17.84 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 226 K | P_flash = 17.84 bar | gamma = 12.232110 mN/m
# T = 226 K | P_flash = 20.29 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 226 K | P_flash = 20.29 bar | gamma = 11.908105 mN/m
# T = 226 K | P_flash = 22.74 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 226 K | P_flash = 22.74 bar | gamma = 11.623027 mN/m
# T = 226 K | P_flash = 25.20 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 226 K | P_flash = 25.20 bar | gamma = 11.377979 mN/m
# T = 226 K | P_flash = 27.65 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 226 K | P_flash = 27.65 bar | gamma = 11.170786 mN/m
# T = 226 K | P_flash = 30.11 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 226 K | P_flash = 30.11 bar | gamma = 10.995952 mN/m
# T = 227 K | P_flash = 8.34 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 227 K | P_flash = 8.34 bar | gamma = 13.661018 mN/m
# T = 227 K | P_flash = 10.78 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 227 K | P_flash = 10.78 bar | gamma = 13.206352 mN/m
# T = 227 K | P_flash = 13.22 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 227 K | P_flash = 13.22 bar | gamma = 12.786791 mN/m
# T = 227 K | P_flash = 15.66 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 227 K | P_flash = 15.66 bar | gamma = 12.400355 mN/m
# T = 227 K | P_flash = 18.10 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 227 K | P_flash = 18.10 bar | gamma = 12.047113 mN/m
# T = 227 K | P_flash = 20.54 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 227 K | P_flash = 20.54 bar | gamma = 11.728839 mN/m
# T = 227 K | P_flash = 22.98 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 227 K | P_flash = 22.98 bar | gamma = 11.447969 mN/m
# T = 227 K | P_flash = 25.42 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 227 K | P_flash = 25.42 bar | gamma = 11.205716 mN/m
# T = 227 K | P_flash = 27.86 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 227 K | P_flash = 27.86 bar | gamma = 11.000241 mN/m
# T = 227 K | P_flash = 30.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 227 K | P_flash = 30.30 bar | gamma = 10.826485 mN/m
# T = 228 K | P_flash = 8.67 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 228 K | P_flash = 8.67 bar | gamma = 13.439384 mN/m
# T = 228 K | P_flash = 11.09 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 228 K | P_flash = 11.09 bar | gamma = 12.995941 mN/m
# T = 228 K | P_flash = 13.52 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 228 K | P_flash = 13.52 bar | gamma = 12.586111 mN/m
# T = 228 K | P_flash = 15.95 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 228 K | P_flash = 15.95 bar | gamma = 12.208060 mN/m
# T = 228 K | P_flash = 18.37 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 228 K | P_flash = 18.37 bar | gamma = 11.861877 mN/m
# T = 228 K | P_flash = 20.80 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 228 K | P_flash = 20.80 bar | gamma = 11.549260 mN/m
# T = 228 K | P_flash = 23.22 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 228 K | P_flash = 23.22 bar | gamma = 11.272587 mN/m
# T = 228 K | P_flash = 25.65 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 228 K | P_flash = 25.65 bar | gamma = 11.033155 mN/m
# T = 228 K | P_flash = 28.08 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 228 K | P_flash = 28.08 bar | gamma = 10.829438 mN/m
# T = 228 K | P_flash = 30.50 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 228 K | P_flash = 30.50 bar | gamma = 10.656788 mN/m
# T = 229 K | P_flash = 9.01 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 229 K | P_flash = 9.01 bar | gamma = 13.218437 mN/m
# T = 229 K | P_flash = 11.42 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 229 K | P_flash = 11.42 bar | gamma = 12.785897 mN/m
# T = 229 K | P_flash = 13.83 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 229 K | P_flash = 13.83 bar | gamma = 12.385550 mN/m
# T = 229 K | P_flash = 16.24 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 229 K | P_flash = 16.24 bar | gamma = 12.015697 mN/m
# T = 229 K | P_flash = 18.66 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 229 K | P_flash = 18.66 bar | gamma = 11.676441 mN/m
# T = 229 K | P_flash = 21.07 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 229 K | P_flash = 21.07 bar | gamma = 11.369412 mN/m
# T = 229 K | P_flash = 23.48 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 229 K | P_flash = 23.48 bar | gamma = 11.096920 mN/m
# T = 229 K | P_flash = 25.89 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 229 K | P_flash = 25.89 bar | gamma = 10.860335 mN/m
# T = 229 K | P_flash = 28.31 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 229 K | P_flash = 28.31 bar | gamma = 10.658411 mN/m
# T = 229 K | P_flash = 30.72 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 229 K | P_flash = 30.72 bar | gamma = 10.486898 mN/m
# T = 230 K | P_flash = 9.36 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 230 K | P_flash = 9.36 bar | gamma = 12.998184 mN/m
# T = 230 K | P_flash = 11.75 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 230 K | P_flash = 11.75 bar | gamma = 12.576245 mN/m
# T = 230 K | P_flash = 14.15 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 230 K | P_flash = 14.15 bar | gamma = 12.185141 mN/m
# T = 230 K | P_flash = 16.55 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 230 K | P_flash = 16.55 bar | gamma = 11.823304 mN/m
# T = 230 K | P_flash = 18.95 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 230 K | P_flash = 18.95 bar | gamma = 11.490847 mN/m
# T = 230 K | P_flash = 21.35 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 230 K | P_flash = 21.35 bar | gamma = 11.189334 mN/m
# T = 230 K | P_flash = 23.75 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 230 K | P_flash = 23.75 bar | gamma = 10.921006 mN/m
# T = 230 K | P_flash = 26.15 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 230 K | P_flash = 26.15 bar | gamma = 10.687290 mN/m
# T = 230 K | P_flash = 28.54 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 230 K | P_flash = 28.54 bar | gamma = 10.487197 mN/m
# T = 230 K | P_flash = 30.94 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 230 K | P_flash = 30.94 bar | gamma = 10.316849 mN/m
# T = 231 K | P_flash = 9.71 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 231 K | P_flash = 9.71 bar | gamma = 12.778636 mN/m
# T = 231 K | P_flash = 12.10 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 231 K | P_flash = 12.10 bar | gamma = 12.367004 mN/m
# T = 231 K | P_flash = 14.48 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 231 K | P_flash = 14.48 bar | gamma = 11.984915 mN/m
# T = 231 K | P_flash = 16.87 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 231 K | P_flash = 16.87 bar | gamma = 11.630916 mN/m
# T = 231 K | P_flash = 19.25 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 231 K | P_flash = 19.25 bar | gamma = 11.305135 mN/m
# T = 231 K | P_flash = 21.64 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 231 K | P_flash = 21.64 bar | gamma = 11.009068 mN/m
# T = 231 K | P_flash = 24.03 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 231 K | P_flash = 24.03 bar | gamma = 10.744885 mN/m
# T = 231 K | P_flash = 26.41 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 231 K | P_flash = 26.41 bar | gamma = 10.514058 mN/m
# T = 231 K | P_flash = 28.80 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 231 K | P_flash = 28.80 bar | gamma = 10.315830 mN/m
# T = 231 K | P_flash = 31.18 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 231 K | P_flash = 31.18 bar | gamma = 10.146677 mN/m
# T = 232 K | P_flash = 10.08 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 232 K | P_flash = 10.08 bar | gamma = 12.559801 mN/m
# T = 232 K | P_flash = 12.45 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 232 K | P_flash = 12.45 bar | gamma = 12.158197 mN/m
# T = 232 K | P_flash = 14.83 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 232 K | P_flash = 14.83 bar | gamma = 11.784901 mN/m
# T = 232 K | P_flash = 17.20 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 232 K | P_flash = 17.20 bar | gamma = 11.438570 mN/m
# T = 232 K | P_flash = 19.57 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 232 K | P_flash = 19.57 bar | gamma = 11.119343 mN/m
# T = 232 K | P_flash = 21.94 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 232 K | P_flash = 21.94 bar | gamma = 10.828650 mN/m
# T = 232 K | P_flash = 24.31 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 232 K | P_flash = 24.31 bar | gamma = 10.568593 mN/m
# T = 232 K | P_flash = 26.69 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 232 K | P_flash = 26.69 bar | gamma = 10.340674 mN/m
# T = 232 K | P_flash = 29.06 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 232 K | P_flash = 29.06 bar | gamma = 10.144345 mN/m
# T = 232 K | P_flash = 31.43 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 232 K | P_flash = 31.43 bar | gamma = 9.976416 mN/m
# T = 233 K | P_flash = 10.46 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 233 K | P_flash = 10.46 bar | gamma = 12.341692 mN/m
# T = 233 K | P_flash = 12.82 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 233 K | P_flash = 12.82 bar | gamma = 11.949845 mN/m
# T = 233 K | P_flash = 15.18 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 233 K | P_flash = 15.18 bar | gamma = 11.585128 mN/m
# T = 233 K | P_flash = 17.54 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 233 K | P_flash = 17.54 bar | gamma = 11.246301 mN/m
# T = 233 K | P_flash = 19.90 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 233 K | P_flash = 19.90 bar | gamma = 10.933509 mN/m
# T = 233 K | P_flash = 22.25 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 233 K | P_flash = 22.25 bar | gamma = 10.648122 mN/m
# T = 233 K | P_flash = 24.61 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 233 K | P_flash = 24.61 bar | gamma = 10.392169 mN/m
# T = 233 K | P_flash = 26.97 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 233 K | P_flash = 26.97 bar | gamma = 10.167173 mN/m
# T = 233 K | P_flash = 29.33 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 233 K | P_flash = 29.33 bar | gamma = 9.972775 mN/m
# T = 233 K | P_flash = 31.69 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 233 K | P_flash = 31.69 bar | gamma = 9.806099 mN/m
# T = 234 K | P_flash = 10.85 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 234 K | P_flash = 10.85 bar | gamma = 12.124316 mN/m
# T = 234 K | P_flash = 13.20 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 234 K | P_flash = 13.20 bar | gamma = 11.741968 mN/m
# T = 234 K | P_flash = 15.54 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 234 K | P_flash = 15.54 bar | gamma = 11.385626 mN/m
# T = 234 K | P_flash = 17.89 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 234 K | P_flash = 17.89 bar | gamma = 11.054142 mN/m
# T = 234 K | P_flash = 20.23 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 234 K | P_flash = 20.23 bar | gamma = 10.747670 mN/m
# T = 234 K | P_flash = 22.58 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 234 K | P_flash = 22.58 bar | gamma = 10.467519 mN/m
# T = 234 K | P_flash = 24.92 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 234 K | P_flash = 24.92 bar | gamma = 10.215648 mN/m
# T = 234 K | P_flash = 27.27 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 234 K | P_flash = 27.27 bar | gamma = 9.993589 mN/m
# T = 234 K | P_flash = 29.61 | z = [0.96  0.003 0.007 0.02  0.01 ]
# ...
# T = 292 K | P_flash = 63.69 bar | gamma = 1.225274 mN/m
# T = 292 K | P_flash = 64.97 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 292 K | P_flash = 64.97 bar | gamma = 1.171698 mN/m
# T = 292 K | P_flash = 66.25 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 292 K | P_flash = 66.25 bar | gamma = 1.119767 mN/m
# T = 292 K | P_flash = 67.53 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 292 K | P_flash = 67.53 bar | gamma = 1.069499 mN/m
# T = 292 K | P_flash = 68.81 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 292 K | P_flash = 68.81 bar | gamma = 1.020924 mN/m
# T = 292 K | P_flash = 70.09 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 292 K | P_flash = 70.09 bar | gamma = 0.974062 mN/m
# T = 292 K | P_flash = 71.37 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 292 K | P_flash = 71.37 bar | gamma = 0.928945 mN/m
# T = 293 K | P_flash = 61.35 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 293 K | P_flash = 61.35 bar | gamma = 1.264283 mN/m
# T = 293 K | P_flash = 62.59 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 293 K | P_flash = 62.59 bar | gamma = 1.209789 mN/m
# T = 293 K | P_flash = 63.83 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 293 K | P_flash = 63.83 bar | gamma = 1.156799 mN/m
# T = 293 K | P_flash = 65.07 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 293 K, P = 65.07 bar: `DFT` did not converge within the maximum number of iterations.
# T = 293 K | P_flash = 65.07 bar | gamma = nan mN/m
# T = 293 K | P_flash = 66.31 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 293 K | P_flash = 66.31 bar | gamma = 1.055336 mN/m
# T = 293 K | P_flash = 67.56 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 293 K, P = 67.56 bar: `DFT` did not converge within the maximum number of iterations.
# T = 293 K | P_flash = 67.56 bar | gamma = nan mN/m
# T = 293 K | P_flash = 68.80 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 293 K | P_flash = 68.80 bar | gamma = 0.959961 mN/m
# T = 293 K | P_flash = 70.04 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 293 K, P = 70.04 bar: `DFT` did not converge within the maximum number of iterations.
# T = 293 K | P_flash = 70.04 bar | gamma = nan mN/m
# T = 293 K | P_flash = 71.28 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 293 K, P = 71.28 bar: `DFT` did not converge within the maximum number of iterations.
# T = 293 K | P_flash = 71.28 bar | gamma = nan mN/m
# T = 293 K | P_flash = 72.52 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 293 K, P = 72.52 bar: `DFT` did not converge within the maximum number of iterations.
# T = 293 K | P_flash = 72.52 bar | gamma = nan mN/m
# T = 294 K | P_flash = 62.88 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 294 K | P_flash = 62.88 bar | gamma = 1.136210 mN/m
# T = 294 K | P_flash = 64.08 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 294 K | P_flash = 64.08 bar | gamma = 1.085681 mN/m
# T = 294 K | P_flash = 65.28 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 294 K | P_flash = 65.28 bar | gamma = 1.036539 mN/m
# T = 294 K | P_flash = 66.48 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 294 K, P = 66.48 bar: `DFT` did not converge within the maximum number of iterations.
# T = 294 K | P_flash = 66.48 bar | gamma = nan mN/m
# T = 294 K | P_flash = 67.68 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 294 K | P_flash = 67.68 bar | gamma = 0.942420 mN/m
# T = 294 K | P_flash = 68.88 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 294 K, P = 68.88 bar: `DFT` did not converge within the maximum number of iterations.
# T = 294 K | P_flash = 68.88 bar | gamma = nan mN/m
# T = 294 K | P_flash = 70.08 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 294 K, P = 70.08 bar: `DFT` did not converge within the maximum number of iterations.
# T = 294 K | P_flash = 70.08 bar | gamma = nan mN/m
# T = 294 K | P_flash = 71.28 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 294 K | P_flash = 71.28 bar | gamma = 0.811791 mN/m
# T = 294 K | P_flash = 72.48 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 294 K, P = 72.48 bar: `DFT` did not converge within the maximum number of iterations.
# T = 294 K | P_flash = 72.48 bar | gamma = nan mN/m
# T = 294 K | P_flash = 73.68 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 294 K | P_flash = 73.68 bar | gamma = 0.731925 mN/m
# T = 295 K | P_flash = 64.45 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 295 K | P_flash = 64.45 bar | gamma = 1.011752 mN/m
# T = 295 K | P_flash = 65.61 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 295 K | P_flash = 65.61 bar | gamma = 0.965193 mN/m
# T = 295 K | P_flash = 66.77 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 295 K | P_flash = 66.77 bar | gamma = 0.919910 mN/m
# T = 295 K | P_flash = 67.92 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 295 K | P_flash = 67.92 bar | gamma = 0.875899 mN/m
# T = 295 K | P_flash = 69.08 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 295 K, P = 69.08 bar: `DFT` did not converge within the maximum number of iterations.
# T = 295 K | P_flash = 69.08 bar | gamma = nan mN/m
# T = 295 K | P_flash = 70.23 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 295 K | P_flash = 70.23 bar | gamma = 0.791719 mN/m
# T = 295 K | P_flash = 71.39 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 295 K, P = 71.39 bar: `DFT` did not converge within the maximum number of iterations.
# T = 295 K | P_flash = 71.39 bar | gamma = nan mN/m
# T = 295 K | P_flash = 72.54 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 295 K, P = 72.54 bar: `DFT` did not converge within the maximum number of iterations.
# T = 295 K | P_flash = 72.54 bar | gamma = nan mN/m
# T = 295 K | P_flash = 73.70 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 295 K | P_flash = 73.70 bar | gamma = 0.675213 mN/m
# T = 295 K | P_flash = 74.86 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 295 K, P = 74.86 bar: `DFT` did not converge within the maximum number of iterations.
# T = 295 K | P_flash = 74.86 bar | gamma = nan mN/m
# T = 296 K | P_flash = 66.06 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 296 K | P_flash = 66.06 bar | gamma = 0.891145 mN/m
# T = 296 K | P_flash = 67.17 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 296 K | P_flash = 67.17 bar | gamma = 0.848568 mN/m
# T = 296 K | P_flash = 68.28 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 296 K, P = 68.28 bar: `DFT` did not converge within the maximum number of iterations.
# T = 296 K | P_flash = 68.28 bar | gamma = nan mN/m
# T = 296 K | P_flash = 69.39 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 296 K, P = 69.39 bar: `DFT` did not converge within the maximum number of iterations.
# T = 296 K | P_flash = 69.39 bar | gamma = nan mN/m
# T = 296 K | P_flash = 70.50 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 296 K, P = 70.50 bar: `DFT` did not converge within the maximum number of iterations.
# T = 296 K | P_flash = 70.50 bar | gamma = nan mN/m
# T = 296 K | P_flash = 71.61 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 296 K, P = 71.61 bar: `DFT` did not converge within the maximum number of iterations.
# T = 296 K | P_flash = 71.61 bar | gamma = nan mN/m
# T = 296 K | P_flash = 72.72 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 296 K, P = 72.72 bar: `DFT` did not converge within the maximum number of iterations.
# T = 296 K | P_flash = 72.72 bar | gamma = nan mN/m
# T = 296 K | P_flash = 73.83 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 296 K, P = 73.83 bar: `DFT` did not converge within the maximum number of iterations.
# T = 296 K | P_flash = 73.83 bar | gamma = nan mN/m
# T = 296 K | P_flash = 74.94 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 296 K | P_flash = 74.94 bar | gamma = 0.583336 mN/m
# T = 296 K | P_flash = 76.05 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 296 K, P = 76.05 bar: `DFT` did not converge within the maximum number of iterations.
# T = 296 K | P_flash = 76.05 bar | gamma = nan mN/m
# T = 297 K | P_flash = 67.71 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 297 K, P = 67.71 bar: `DFT` did not converge within the maximum number of iterations.
# T = 297 K | P_flash = 67.71 bar | gamma = nan mN/m
# T = 297 K | P_flash = 68.77 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 297 K, P = 68.77 bar: `DFT` did not converge within the maximum number of iterations.
# T = 297 K | P_flash = 68.77 bar | gamma = nan mN/m
# T = 297 K | P_flash = 69.83 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 297 K | P_flash = 69.83 bar | gamma = 0.698562 mN/m
# T = 297 K | P_flash = 70.89 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 297 K, P = 70.89 bar: `DFT` did not converge within the maximum number of iterations.
# T = 297 K | P_flash = 70.89 bar | gamma = nan mN/m
# T = 297 K | P_flash = 71.95 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 297 K, P = 71.95 bar: `DFT` did not converge within the maximum number of iterations.
# T = 297 K | P_flash = 71.95 bar | gamma = nan mN/m
# T = 297 K | P_flash = 73.01 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 297 K, P = 73.01 bar: `DFT` did not converge within the maximum number of iterations.
# T = 297 K | P_flash = 73.01 bar | gamma = nan mN/m
# T = 297 K | P_flash = 74.07 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 297 K | P_flash = 74.07 bar | gamma = 0.559055 mN/m
# T = 297 K | P_flash = 75.13 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 297 K, P = 75.13 bar: `DFT` did not converge within the maximum number of iterations.
# T = 297 K | P_flash = 75.13 bar | gamma = nan mN/m
# T = 297 K | P_flash = 76.19 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 297 K | P_flash = 76.19 bar | gamma = 0.495783 mN/m
# T = 297 K | P_flash = 77.24 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 297 K | P_flash = 77.24 bar | gamma = 0.465787 mN/m
# T = 298 K | P_flash = 69.40 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 298 K, P = 69.40 bar: `DFT` did not converge within the maximum number of iterations.
# T = 298 K | P_flash = 69.40 bar | gamma = nan mN/m
# T = 298 K | P_flash = 70.41 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 298 K, P = 70.41 bar: `DFT` did not converge within the maximum number of iterations.
# T = 298 K | P_flash = 70.41 bar | gamma = nan mN/m
# T = 298 K | P_flash = 71.41 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 298 K, P = 71.41 bar: `DFT` did not converge within the maximum number of iterations.
# T = 298 K | P_flash = 71.41 bar | gamma = nan mN/m
# T = 298 K | P_flash = 72.42 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 298 K, P = 72.42 bar: `DFT` did not converge within the maximum number of iterations.
# T = 298 K | P_flash = 72.42 bar | gamma = nan mN/m
# T = 298 K | P_flash = 73.42 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 298 K, P = 73.42 bar: `DFT` did not converge within the maximum number of iterations.
# T = 298 K | P_flash = 73.42 bar | gamma = nan mN/m
# T = 298 K | P_flash = 74.43 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 298 K, P = 74.43 bar: `DFT` did not converge within the maximum number of iterations.
# T = 298 K | P_flash = 74.43 bar | gamma = nan mN/m
# T = 298 K | P_flash = 75.44 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 298 K, P = 75.44 bar: `DFT` did not converge within the maximum number of iterations.
# T = 298 K | P_flash = 75.44 bar | gamma = nan mN/m
# T = 298 K | P_flash = 76.44 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 298 K, P = 76.44 bar: `DFT` did not converge within the maximum number of iterations.
# T = 298 K | P_flash = 76.44 bar | gamma = nan mN/m
# T = 298 K | P_flash = 77.45 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 298 K, P = 77.45 bar: `DFT` did not converge within the maximum number of iterations.
# T = 298 K | P_flash = 77.45 bar | gamma = nan mN/m
# T = 298 K | P_flash = 78.45 | z = [0.96  0.003 0.007 0.02  0.01 ]
# Surface tension calculation failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 298 K, P = 78.45 bar: `DFT` did not converge within the maximum number of iterations.
# T = 298 K | P_flash = 78.45 bar | gamma = nan mN/m
# T = 302 K | P_flash = 83.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# TP flash failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 302 K, P = 83.30 bar: No phase split according to stability analysis.
# T = 302 K | P_flash = 83.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# TP flash failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 302 K, P = 83.30 bar: No phase split according to stability analysis.
# T = 302 K | P_flash = 83.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# TP flash failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 302 K, P = 83.30 bar: No phase split according to stability analysis.
# T = 302 K | P_flash = 83.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# TP flash failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 302 K, P = 83.30 bar: No phase split according to stability analysis.
# T = 302 K | P_flash = 83.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# TP flash failed for z = [0.96  0.003 0.007 0.02  0.01 ] at T = 302 K, P = 83.30 bar: No phase split according to stability analysis.
# T = 302 K | P_flash = 83.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 302 K | P_flash = 83.30 bar | gamma = 0.123880 mN/m
# T = 302 K | P_flash = 83.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 302 K | P_flash = 83.30 bar | gamma = 0.123885 mN/m
# T = 302 K | P_flash = 83.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 302 K | P_flash = 83.30 bar | gamma = 0.123883 mN/m
# T = 302 K | P_flash = 83.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 302 K | P_flash = 83.30 bar | gamma = 0.123883 mN/m
# T = 302 K | P_flash = 83.30 | z = [0.96  0.003 0.007 0.02  0.01 ]
# T = 302 K | P_flash = 83.30 bar | gamma = 0.123886 mN/m
# Available feeds: ['feed_1']
# feed_1: 100 bubble pts, 102 dew pts, 100 isotherms, 995 interfacial pts
# {'feed_1': {'n_bubble_points': 100, 'n_dew_points': 102, 'n_isotherms': 100, 'total_interfacial_points': 995}}
# Saved 995 rows to CSV/interfacial_results/feed_1_interfacial_results.csv
# Saved phase envelope data to CSV/phase_envelope/feed_1_phase_envelope.csv

# %%
notebook_end    = time.perf_counter()
elapsed_minutes = (notebook_end - notebook_start) / 60
print(f"Total notebook runtime: {elapsed_minutes:.2f} minutes")
# Out:
# Total notebook runtime: 13.43 minutes
